# %%
import openpyxl
import json
from typing import Dict, Any, Optional, List, Tuple
from dataclasses import dataclass
from pathlib import Path

@dataclass
class FieldConfig:
    """Configuration for each field to extract"""
    name: str
    positions: List[Tuple[int, int]]  # (row, col) tuples only

def make_field_range(name: str, rows: range, col: int) -> FieldConfig:
    """Create a FieldConfig from a row range and a single column"""
    return FieldConfig(name, [(r, col) for r in rows])
def make_middle( row: int, col: int) -> FieldConfig:
    fields = []
    name=["customer","manufacturer","sevensix"]
    for i in range(3):
        rows = range(row+i*5,row+i*5+5)
        fields.extend([FieldConfig("ai_"+name[i]+"_who", [(r, col) for r in rows]),
        FieldConfig("ai_"+name[i]+"_what", [(r, col+1) for r in rows]),
        FieldConfig("ai_"+name[i]+"_when", [(r, col+5) for r in rows])])
    return fields

def make_case_fields(case_no: int, start_row: int, start_col: int = 6) -> List[FieldConfig]:
    """
    Generate FieldConfigs for a case block.
    case_no: number suffix (1,2,3,...)
    start_row: top row of the case block
    start_col: first column (default=6 for your sheet)
    """
    fields = [
        ("customer_name", (start_row, start_col)),
        ("customer_representative", (start_row, start_col+1)),
        ("occurrence_date", (start_row, start_col+2)),
        ("branch", (start_row, start_col+3)),
        ("application", (start_row+1, start_col)),
        ("manufacturer", (start_row+2, start_col)),
        ("product", (start_row+3, start_col)),
        ("competitive", (start_row+4, start_col)),
        ("amount", (start_row+5, start_col)),
        ("order_month", (start_row+6, start_col)),
        ("budget", (start_row+7, start_col)),
        ("probability", (start_row+8, start_col)),
    ]
    return [FieldConfig(f"case{case_no}_{fname}", [pos]) for fname, pos in fields]

class ExcelDataExtractor:
    """Optimized Excel data extractor (template positions only)"""
    
    def __init__(self):
        self.fields = [
            # Basic Information
            FieldConfig("reporter_name", [(2,4), (2,5), (2,6)]),
            FieldConfig("date", [(3,4), (3,5)]),
            FieldConfig("location", [(4,4), (4,5)]),
            
            # Customer Information
            make_field_range("customer_company_name", range(7, 11), 4),
            make_field_range("customer_department", range(7, 12), 5),
            make_field_range("customer_full_name", range(7, 12), 6),
            FieldConfig("customer_number", [(11,4)]),

            # Manufacturer Information
            make_field_range("manufacturer_company_name", range(7, 11), 7),
            make_field_range("manufacturer_department", range(7, 11), 8),
            make_field_range("manufacturer_full_name", range(7, 11), 9),
            FieldConfig("sevensix", [(7,10),(8,10),(9,10),(10,10)]),
            
            
        ]
        
        # Add multiple case blocks easily
        
        # define columns for middle-table
        
    
    def adjust_fields_by_dimension(self, ws):
        extra_fields = []
        print(ws.max_row)
        if ws.max_row==71:
            self.fields+=[
                # Business Information
            FieldConfig("purpose", [(12,4),(13,4),(16,4)]),
            FieldConfig("free_description", [(17,4),(18,4)]),
            FieldConfig("associated_customer_name", [(35,4)]),
            FieldConfig("competitive_information", [(36,4)]),]
            self.fields.extend(make_middle(20,5))
            self.fields += make_case_fields(case_no=1, start_row=38)
            self.fields += make_case_fields(case_no=2, start_row=48)  # example second case at row 50
            self.fields += make_case_fields(case_no=3, start_row=58)  # third case, etc.
        # check rows
        if ws.max_row == 97:
            self.fields+=[FieldConfig("annual_project_name", [(17,4),(17,5),(17,6)]),
                          FieldConfig("annual_project_schedule", [(18,4),(18,5),(18,6)]),
                          FieldConfig("annual_project_budget", [(19,4),(19,5),(19,6)]),
                          FieldConfig("free_description", [(20,4),(20,5)]),
                          FieldConfig("associated_customer_name", [(46,4)]),
                          FieldConfig("competitive_information", [(47,4)]),
                          ]
            self.fields.extend(make_middle(31,5))

            self.fields += make_case_fields(case_no=1, start_row=49)
            self.fields += make_case_fields(case_no=2, start_row=59)  # example second case at row 50
            self.fields += make_case_fields(case_no=3, start_row=69)  # third case, etc.
            self.fields += make_case_fields(case_no=4, start_row=79)
            self.fields += make_case_fields(case_no=5, start_row=89)



    # ----------- MAIN EXTRACTION ----------
    def extract_from_file(self, file_path: str) -> Dict[str, Any]:
        """Extract values only from predefined positions"""
        try:
            wb = openpyxl.load_workbook(file_path, data_only=True)
            ws = wb.active
            print(f"Processing: {Path(file_path).name} ({ws.title}, {ws.max_row}x{ws.max_column})")
            self.adjust_fields_by_dimension(ws)
            extracted, stats = {}, {"found": 0, "not_found": 0}

            for field in self.fields:
                value = self._extract_field(ws, field)
                extracted[field.name] = value
                stats["found" if value else "not_found"] += 1
            
            results = {
                "data": extracted, 
                "file_info": {
                    "filename": Path(file_path).name,
                    "worksheet": ws.title,
                    "dimensions": f"{ws.max_row}x{ws.max_column}"
                },
                "extraction_stats": {
                    **stats,
                    "total_fields": len(self.fields),
                    "success_rate": f"{(stats['found']/len(self.fields))*100:.1f}%"
                }
            }
            # self._print_summary(results)
            return results
        except Exception as e:
            print(f"❌ Error: {e}")
            return {"error": str(e)}

    # ----------- FIELD EXTRACTION ----------
    def _extract_field(self, ws, field: FieldConfig) -> Optional[str]:
        """Extract value only from predefined positions"""
        values = [
            str(ws.cell(row=r, column=c).value).strip()
            for r, c in field.positions
            if ws.cell(row=r, column=c).value not in (None, "")
        ]
        if values:
            return "\n".join(values) if len(values) > 1 else values[0]
        return None

    # ----------- UTILITIES ----------
    def _print_summary(self, results: Dict[str, Any]):
        if "error" in results:
            print(f"❌ Extraction failed: {results['error']}")
            return
        stats = results["extraction_stats"]
        print(f"\n{'='*50}\nEXTRACTION SUMMARY\n{'='*50}")
        print(f"📊 Success Rate: {stats['success_rate']}")
        print(f"✅ Found: {stats['found']}")
        print(f"❌ Not found: {stats['not_found']}")
        print(f"📋 Total fields: {stats['total_fields']}")

    def save_results(self, results: Dict[str, Any], output_file: str):
        try:
            with open(output_file, "w", encoding="utf-8") as f:
                json.dump(results, f, ensure_ascii=False, indent=2)
            print(f"💾 Saved: {output_file}")
        except Exception as e:
            print(f"❌ Save failed: {e}")

    def batch_process(self, files: List[str], output_dir: str = "outputs") -> List[Dict[str, Any]]:
        Path(output_dir).mkdir(exist_ok=True)
        all_results = []
        print(f"🔄 Processing {len(files)} files...")
        for i, file in enumerate(files, 1):
            print(f"\n[{i}/{len(files)}] {Path(file).name}")
            result = self.extract_from_file(file)
            
            if result and "data" in result:
                all_results.append(result)
                self.save_results(result, str(Path(output_dir) / f"{Path(file).stem}_extracted.json"))
                
            # if i> 10:
            #     break
        self.save_results({"extractions": all_results}, str(Path(output_dir) / "all_extractions.json"))
        return all_results
    

    def list_excel_files(self,source_dir: str, extensions=("*.xlsx", "*.xlsm")) -> list[str]:
        """Return list of Excel files from a directory"""
        p = Path(source_dir)
        files = []
        for ext in extensions:
            files.extend(p.rglob(ext))  # rglob → recursive search
        return [str(f) for f in files]

    # Example usage
if __name__ == "__main__":
    # Single file processing
    source_dir = "Sevensix_dropbox/機密レベル2/営業本部/営業活動/営業報告書"
    extractor = ExcelDataExtractor()
    file_list = extractor.list_excel_files(source_dir)
    # results = extractor.batch_process(files=["20250602_blueqat_港様_v_清水 (4) (1).xlsx"])
    results = extractor.batch_process(files=file_list)
# Out:
# 🔄 Processing 555 files...
#
# [1/555] 20250701_NTTイノベーティブデバイス_守屋様_V_上瀬（20250623）.xlsm
# Processing: 20250701_NTTイノベーティブデバイス_守屋様_V_上瀬（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250701_NTTイノベーティブデバイス_守屋様_V_上瀬（20250623）_extracted.json
#
# [2/555] 20250623_クアンテックー上瀧英郎_V_山下真弘（追記）.xlsm
# Processing: 20250623_クアンテックー上瀧英郎_V_山下真弘（追記）.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250623_クアンテックー上瀧英郎_V_山下真弘（追記）_extracted.json
#
# [3/555] 20250606_名古屋大学_久野先生_V_河合.xlsm
# Processing: 20250606_名古屋大学_久野先生_V_河合.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_名古屋大学_久野先生_V_河合_extracted.json
#
# [4/555] 20250722_富士通_蘇武洋平_R_大久保.xlsm
# Processing: 20250722_富士通_蘇武洋平_R_大久保.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250722_富士通_蘇武洋平_R_大久保_extracted.json
#
# [5/555] 20250718_NICT_北村光雄_V_清水卓也.xlsm
# Processing: 20250718_NICT_北村光雄_V_清水卓也.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250718_NICT_北村光雄_V_清水卓也_extracted.json
#
# [6/555] 20250707_長岡技術科学大学_岩橋様_V_久保寺（20250623）.xlsm
# Processing: 20250707_長岡技術科学大学_岩橋様_V_久保寺（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250707_長岡技術科学大学_岩橋様_V_久保寺（20250623）_extracted.json
#
# [7/555] 20250710_国立天文台_入札_V_大久保.xlsm
# Processing: 20250710_国立天文台_入札_V_大久保.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250710_国立天文台_入札_V_大久保_extracted.json
#
# [8/555] 20250715_NTT-ATクリエイティブ_安藝様_確度進捗_鎌田.xlsm
# Processing: 20250715_NTT-ATクリエイティブ_安藝様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250715_NTT-ATクリエイティブ_安藝様_確度進捗_鎌田_extracted.json
#
# [9/555] 20250715_椿本興業_小森_V_安野.xlsm
# Processing: 20250715_椿本興業_小森_V_安野.xlsm (報告書, 88x21)
# 88
# 💾 Saved: outputs/20250715_椿本興業_小森_V_安野_extracted.json
#
# [10/555] 20250616_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm
# Processing: 20250616_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250616_高輝度光科学研究センター_松原様_確度進捗_鎌田_extracted.json
#
# [11/555] 20250603_NTTイノベーティブデバイス_本田様_確度進捗_清水.xlsm
# Processing: 20250603_NTTイノベーティブデバイス_本田様_確度進捗_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250603_NTTイノベーティブデバイス_本田様_確度進捗_清水_extracted.json
#
# [12/555] 20250714_徳島大学_檜垣様_確度進捗_鎌田.xlsm
# Processing: 20250714_徳島大学_檜垣様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250714_徳島大学_檜垣様_確度進捗_鎌田_extracted.json
#
# [13/555] 20250603_理研生命機能科学研究センター_森下喜弘先生_R_山下真弘.xlsm
# Processing: 20250603_理研生命機能科学研究センター_森下喜弘先生_R_山下真弘.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250603_理研生命機能科学研究センター_森下喜弘先生_R_山下真弘_extracted.json
#
# [14/555] 20250707_岐阜大学_久武研究室　小島様_V_河合.xlsm
# Processing: 20250707_岐阜大学_久武研究室　小島様_V_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250707_岐阜大学_久武研究室　小島様_V_河合_extracted.json
#
# [15/555] 20250707_徳島大学_久世先生_確度進捗_鎌田.xlsm
# Processing: 20250707_徳島大学_久世先生_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250707_徳島大学_久世先生_確度進捗_鎌田_extracted.json
#
# [16/555] 20250617_浜松ホトニクス_森田様_R_河合.xlsm
# Processing: 20250617_浜松ホトニクス_森田様_R_河合.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250617_浜松ホトニクス_森田様_R_河合_extracted.json
#
# [17/555] 20250619_電気通信大学_酒井 剛 先生_V_津江.xlsm
# Processing: 20250619_電気通信大学_酒井 剛 先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_電気通信大学_酒井 剛 先生_V_津江_extracted.json
#
# [18/555] 20250718_トライオプティクス_高和様_R_河合.xlsm
# Processing: 20250718_トライオプティクス_高和様_R_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250718_トライオプティクス_高和様_R_河合_extracted.json
#
# [19/555] 20250606_北海道大学_森田隆二_V_清水.xlsm
# Processing: 20250606_北海道大学_森田隆二_V_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_北海道大学_森田隆二_V_清水_extracted.json
#
# [20/555] 20250619_Nikon_Sakai_V_Ohashi.xlsm
# Processing: 20250619_Nikon_Sakai_V_Ohashi.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_Nikon_Sakai_V_Ohashi_extracted.json
#
# [21/555] 20250625_東京大学_種村 拓夫 先生_V_津江.xlsm
# Processing: 20250625_東京大学_種村 拓夫 先生_V_津江.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250625_東京大学_種村 拓夫 先生_V_津江_extracted.json
#
# [22/555] 20250605_ディスコ_前田様_V_久保寺.xlsm
# Processing: 20250605_ディスコ_前田様_V_久保寺.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250605_ディスコ_前田様_V_久保寺_extracted.json
#
# [23/555] 20250625_JVCケンウッド_薄井大輔_V_大久保.xlsm
# Processing: 20250625_JVCケンウッド_薄井大輔_V_大久保.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250625_JVCケンウッド_薄井大輔_V_大久保_extracted.json
#
# [24/555] 20250716_NTTデバイスイノベーションセンタ(厚木)_山田友輝_V_清水.xlsm
# Processing: 20250716_NTTデバイスイノベーションセンタ(厚木)_山田友輝_V_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250716_NTTデバイスイノベーションセンタ(厚木)_山田友輝_V_清水_extracted.json
#
# [25/555] 20250618_NIMS_古瀬 裕章_確度進捗_津江.xlsm
# Processing: 20250618_NIMS_古瀬 裕章_確度進捗_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250618_NIMS_古瀬 裕章_確度進捗_津江_extracted.json
#
# [26/555] 20250604_東芝_西野様_V確度進捗_宮田.xlsm
# Processing: 20250604_東芝_西野様_V確度進捗_宮田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250604_東芝_西野様_V確度進捗_宮田_extracted.json
#
# [27/555] 20250610_NTTイノベーティブデバイス_本田様_確度進捗_清水.xlsm
# Processing: 20250610_NTTイノベーティブデバイス_本田様_確度進捗_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250610_NTTイノベーティブデバイス_本田様_確度進捗_清水_extracted.json
#
# [28/555] 20250724_ZTEジャパン株式会社_ネットワーク事業部_V_ 杉山啓太.xlsm
# Processing: 20250724_ZTEジャパン株式会社_ネットワーク事業部_V_ 杉山啓太.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_ZTEジャパン株式会社_ネットワーク事業部_V_ 杉山啓太_extracted.json
#
# [29/555] 20250605_フォトニック・エッジ_杉山様_V_河合.xlsm
# Processing: 20250605_フォトニック・エッジ_杉山様_V_河合.xlsm (営業 (フォーマット案_営業本部）, 81x21)
# 81
# /Users/jbc/Documents/SevenSix/ETL_pipeline/.venv/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 💾 Saved: outputs/20250605_フォトニック・エッジ_杉山様_V_河合_extracted.json
#
# [30/555] 20250620_産総研_黒須_V_安野.xlsm
# Processing: 20250620_産総研_黒須_V_安野.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250620_産総研_黒須_V_安野_extracted.json
#
# [31/555] 20250711_東京大学_北折曉 先生_V_津江.xlsm
# Processing: 20250711_東京大学_北折曉 先生_V_津江.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250711_東京大学_北折曉 先生_V_津江_extracted.json
#
# [32/555] 20250729_東京大学_井手口様_V確度進捗_宮田.xlsm
# Processing: 20250729_東京大学_井手口様_V確度進捗_宮田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250729_東京大学_井手口様_V確度進捗_宮田_extracted.json
#
# [33/555] 20250627_NTTイノベーティブデバイス_坂本様_V_上瀬（20250623）.xlsm
# Processing: 20250627_NTTイノベーティブデバイス_坂本様_V_上瀬（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250627_NTTイノベーティブデバイス_坂本様_V_上瀬（20250623）_extracted.json
#
# [34/555] 20250703_レーザーシステム_駒形方彦_V_山下真弘.xlsm
# Processing: 20250703_レーザーシステム_駒形方彦_V_山下真弘.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250703_レーザーシステム_駒形方彦_V_山下真弘_extracted.json
#
# [35/555] 20250613_岡本オプティクス_三上拓哉_R_安野.xlsm
# Processing: 20250613_岡本オプティクス_三上拓哉_R_安野.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250613_岡本オプティクス_三上拓哉_R_安野_extracted.json
#
# [36/555] 20250610_四国総合研究所_大井様_確度進捗_鎌田.xlsm
# Processing: 20250610_四国総合研究所_大井様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250610_四国総合研究所_大井様_確度進捗_鎌田_extracted.json
#
# [37/555] 20250603_東京大学_瀧田 正人 先生_V_津江.xlsm
# Processing: 20250603_東京大学_瀧田 正人 先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250603_東京大学_瀧田 正人 先生_V_津江_extracted.json
#
# [38/555] 20250620_近畿大学（福岡）_笠原様_確度進捗_鎌田.xlsm
# Processing: 20250620_近畿大学（福岡）_笠原様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250620_近畿大学（福岡）_笠原様_確度進捗_鎌田_extracted.json
#
# [39/555] 20250619_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm
# Processing: 20250619_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_高輝度光科学研究センター_松原様_確度進捗_鎌田_extracted.json
#
# [40/555] 20250716_NTTイノベーティブデバイス厚木_遠藤様_V_清水.xlsm
# Processing: 20250716_NTTイノベーティブデバイス厚木_遠藤様_V_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250716_NTTイノベーティブデバイス厚木_遠藤様_V_清水_extracted.json
#
# [41/555] 20250609_徳島大学_檜垣様_確度進捗_鎌田.xlsm
# Processing: 20250609_徳島大学_檜垣様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250609_徳島大学_檜垣様_確度進捗_鎌田_extracted.json
#
# [42/555] 20250609_パワーレーザー_加藤_V_加賀.xlsm
# Processing: 20250609_パワーレーザー_加藤_V_加賀.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250609_パワーレーザー_加藤_V_加賀_extracted.json
#
# [43/555] 20250724_東京大学_藤田貴啓先生_V_津江.xlsm
# Processing: 20250724_東京大学_藤田貴啓先生_V_津江.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_東京大学_藤田貴啓先生_V_津江_extracted.json
#
# [44/555] 20250703_NICT_住本浩之_V_清水卓也.xlsm
# Processing: 20250703_NICT_住本浩之_V_清水卓也.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250703_NICT_住本浩之_V_清水卓也_extracted.json
#
# [45/555] 20250616_徳島大学_天野様_確度進捗_鎌田.xlsm
# Processing: 20250616_徳島大学_天野様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250616_徳島大学_天野様_確度進捗_鎌田_extracted.json
#
# [46/555] 20250603_産総研ー_市川卓人_確度進捗_山下真弘.xlsm
# Processing: 20250603_産総研ー_市川卓人_確度進捗_山下真弘.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250603_産総研ー_市川卓人_確度進捗_山下真弘_extracted.json
#
# [47/555] 20250722_ニューメディア_八木澤_R_杉山.xlsm
# Processing: 20250722_ニューメディア_八木澤_R_杉山.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250722_ニューメディア_八木澤_R_杉山_extracted.json
#
# [48/555] 20250715_宇都宮大学_山本先生_確度進捗_鎌田.xlsm
# Processing: 20250715_宇都宮大学_山本先生_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250715_宇都宮大学_山本先生_確度進捗_鎌田_extracted.json
#
# [49/555] 20250709_Blue Laser Fusion_小原様_確度進捗_鎌田.xlsm
# Processing: 20250709_Blue Laser Fusion_小原様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250709_Blue Laser Fusion_小原様_確度進捗_鎌田_extracted.json
#
# [50/555] 20250605_パワーレーザー_加藤_T_加賀.xlsm
# Processing: 20250605_パワーレーザー_加藤_T_加賀.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250605_パワーレーザー_加藤_T_加賀_extracted.json
#
# [51/555] 20250623_四国総合研究所_大井様_確度進捗_鎌田.xlsm
# Processing: 20250623_四国総合研究所_大井様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250623_四国総合研究所_大井様_確度進捗_鎌田_extracted.json
#
# [52/555] 20250624_原田産業_小山肇_R_大久保.xlsm
# Processing: 20250624_原田産業_小山肇_R_大久保.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250624_原田産業_小山肇_R_大久保_extracted.json
#
# [53/555] 20250604_徳島大学_安井様_確度進捗_鎌田.xlsm
# Processing: 20250604_徳島大学_安井様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250604_徳島大学_安井様_確度進捗_鎌田_extracted.json
#
# [54/555] 20250725_三菱電機_秋山智浩_V_清水.xlsm
# Processing: 20250725_三菱電機_秋山智浩_V_清水.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250725_三菱電機_秋山智浩_V_清水_extracted.json
#
# [55/555] 20250610_電気通信大学_菅 哲朗 先生_V_津江.xlsm
# Processing: 20250610_電気通信大学_菅 哲朗 先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250610_電気通信大学_菅 哲朗 先生_V_津江_extracted.json
#
# [56/555] 20250707_フォトニック・エッジ_杉山様_V_河合.xlsm
# Processing: 20250707_フォトニック・エッジ_杉山様_V_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250707_フォトニック・エッジ_杉山様_V_河合_extracted.json
#
# [57/555] 20250704_NTTイノベーティブデバイス_陣内様_V_上瀬（20250623）.xlsm
# Processing: 20250704_NTTイノベーティブデバイス_陣内様_V_上瀬（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250704_NTTイノベーティブデバイス_陣内様_V_上瀬（20250623）_extracted.json
#
# [58/555] 20250702_Blue Laser Fusion_小原様_確度進捗_鎌田.xlsm
# Processing: 20250702_Blue Laser Fusion_小原様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250702_Blue Laser Fusion_小原様_確度進捗_鎌田_extracted.json
#
# [59/555] 20250708_東海岡谷機材_中井様_R_河合.xlsm
# Processing: 20250708_東海岡谷機材_中井様_R_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250708_東海岡谷機材_中井様_R_河合_extracted.json
#
# [60/555] 20250723_ディスコ_川澄様_V_久保寺（20250723）.xlsm
# Processing: 20250723_ディスコ_川澄様_V_久保寺（20250723）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250723_ディスコ_川澄様_V_久保寺（20250723）_extracted.json
#
# [61/555] 20250624_NTT_阿部真志_R_清水（20250623）.xlsm
# Processing: 20250624_NTT_阿部真志_R_清水（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250624_NTT_阿部真志_R_清水（20250623）_extracted.json
#
# [62/555] 20250702_アライドテレシス_佐藤理恵子_V_大久保.xlsm
# Processing: 20250702_アライドテレシス_佐藤理恵子_V_大久保.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250702_アライドテレシス_佐藤理恵子_V_大久保_extracted.json
#
# [63/555] 20250606_千歳科学技術大_大島大輔_V_清水.xlsm
# Processing: 20250606_千歳科学技術大_大島大輔_V_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_千歳科学技術大_大島大輔_V_清水_extracted.json
#
# [64/555] 20250725_Blue Laser Fusion_小原様__鎌田（20250725）.xlsm
# Processing: 20250725_Blue Laser Fusion_小原様__鎌田（20250725）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250725_Blue Laser Fusion_小原様__鎌田（20250725）_extracted.json
#
# [65/555] 20250717_Nikon_Fujimitsu_T_Ohashi.xlsm
# Processing: 20250717_Nikon_Fujimitsu_T_Ohashi.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250717_Nikon_Fujimitsu_T_Ohashi_extracted.json
#
# [66/555] 20250613_宇都宮大学_山本様_確度進捗_鎌田.xlsm
# Processing: 20250613_宇都宮大学_山本様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250613_宇都宮大学_山本様_確度進捗_鎌田_extracted.json
#
# [67/555] 20250610_東京エレクトロンテクノロジソリューションズーラジェンドランスーラジ_R_山下真弘.xlsm
# Processing: 20250610_東京エレクトロンテクノロジソリューションズーラジェンドランスーラジ_R_山下真弘.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250610_東京エレクトロンテクノロジソリューションズーラジェンドランスーラジ_R_山下真弘_extracted.json
#
# [68/555] 20250619_株式会社アマダー井原鈴歌_V_山下真弘.xlsm
# Processing: 20250619_株式会社アマダー井原鈴歌_V_山下真弘.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_株式会社アマダー井原鈴歌_V_山下真弘_extracted.json
#
# [69/555] 20250704_NTTデバイスオプテック_細貝様_V_上瀬（20250623）.xlsm
# Processing: 20250704_NTTデバイスオプテック_細貝様_V_上瀬（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250704_NTTデバイスオプテック_細貝様_V_上瀬（20250623）_extracted.json
#
# [70/555] 20250704_Blue Laser Fusion_小原様_確度進捗_鎌田.xlsm
# Processing: 20250704_Blue Laser Fusion_小原様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250704_Blue Laser Fusion_小原様_確度進捗_鎌田_extracted.json
#
# [71/555] 20250626_理化学研究所_山口様_V_宮田.xlsm
# Processing: 20250626_理化学研究所_山口様_V_宮田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250626_理化学研究所_山口様_V_宮田_extracted.json
#
# [72/555] 20250724_大分ケーブルテレコム_羽田翔太_V_ 杉山啓太.xlsm
# Processing: 20250724_大分ケーブルテレコム_羽田翔太_V_ 杉山啓太.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_大分ケーブルテレコム_羽田翔太_V_ 杉山啓太_extracted.json
#
# [73/555] 20250616_TOMEY　吉田様_V_河合_hane修正_加賀追記.xlsm
# Processing: 20250616_TOMEY　吉田様_V_河合_hane修正_加賀追記.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250616_TOMEY　吉田様_V_河合_hane修正_加賀追記_extracted.json
#
# [74/555] 20250602_高輝度光科学研究センター_松原様_確度進捗_セブンシックス鎌田.xlsm
# Processing: 20250602_高輝度光科学研究センター_松原様_確度進捗_セブンシックス鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250602_高輝度光科学研究センター_松原様_確度進捗_セブンシックス鎌田_extracted.json
#
# [75/555] 20250611_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm
# Processing: 20250611_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250611_高輝度光科学研究センター_松原様_確度進捗_鎌田_extracted.json
#
# [76/555] 20250612__丸紅情報システムズ_大沼_V_杉山.xlsm
# Processing: 20250612__丸紅情報システムズ_大沼_V_杉山.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612__丸紅情報システムズ_大沼_V_杉山_extracted.json
#
# [77/555] 20250606_北海道大学_片山司_V_森田.xlsm
# Processing: 20250606_北海道大学_片山司_V_森田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_北海道大学_片山司_V_森田_extracted.json
#
# [78/555] 20250620_西川計測_岩川峻大_V_大久保.xlsm
# Processing: 20250620_西川計測_岩川峻大_V_大久保.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250620_西川計測_岩川峻大_V_大久保_extracted.json
#
# [79/555] 20250618_徳島大学_安井様_確度進捗_鎌田.xlsm
# Processing: 20250618_徳島大学_安井様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250618_徳島大学_安井様_確度進捗_鎌田_extracted.json
#
# [80/555] 20250612_シンクランド太田和哉_V_清水.xlsm
# Processing: 20250612_シンクランド太田和哉_V_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_シンクランド太田和哉_V_清水_extracted.json
#
# [81/555] 20250728_Blue Laser Fusion_小原様__鎌田（20250728）.xlsm
# Processing: 20250728_Blue Laser Fusion_小原様__鎌田（20250728）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250728_Blue Laser Fusion_小原様__鎌田（20250728）_extracted.json
#
# [82/555] 20250603_NEC_中村康平_確度進捗_大久保.xlsm
# Processing: 20250603_NEC_中村康平_確度進捗_大久保.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250603_NEC_中村康平_確度進捗_大久保_extracted.json
#
# [83/555] 20250619_九大_加藤和利_V_安野.xlsm
# Processing: 20250619_九大_加藤和利_V_安野.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_九大_加藤和利_V_安野_extracted.json
#
# [84/555] 20250612_santec_桜井康樹_V_安野.xlsm
# Processing: 20250612_santec_桜井康樹_V_安野.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_santec_桜井康樹_V_安野_extracted.json
#
# [85/555] 20250605_フォトニックサイエンステクノロジ_須田様_V_清水.xlsm
# Processing: 20250605_フォトニックサイエンステクノロジ_須田様_V_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250605_フォトニックサイエンステクノロジ_須田様_V_清水_extracted.json
#
# [86/555] 20250723_東京科学大学_松井宏樹_V・確度進捗_宮田.xlsm
# Processing: 20250723_東京科学大学_松井宏樹_V・確度進捗_宮田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250723_東京科学大学_松井宏樹_V・確度進捗_宮田_extracted.json
#
# [87/555] 20250704_伊藤電機_山岸_V_安野.xlsm
# Processing: 20250704_伊藤電機_山岸_V_安野.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250704_伊藤電機_山岸_V_安野_extracted.json
#
# [88/555] 20250718_兵庫県立大学_榎原先生_確度進捗_鎌田.xlsm
# Processing: 20250718_兵庫県立大学_榎原先生_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250718_兵庫県立大学_榎原先生_確度進捗_鎌田_extracted.json
#
# [89/555] 20250618_ディスコ_牛窪_V_久保寺.xlsm
# Processing: 20250618_ディスコ_牛窪_V_久保寺.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250618_ディスコ_牛窪_V_久保寺_extracted.json
#
# [90/555] 20250710_徳島大学_安井先生_確度進捗_鎌田.xlsm
# Processing: 20250710_徳島大学_安井先生_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250710_徳島大学_安井先生_確度進捗_鎌田_extracted.json
#
# [91/555] 20250611_阪大_髙橋圭介_R_安野.xlsm
# Processing: 20250611_阪大_髙橋圭介_R_安野.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250611_阪大_髙橋圭介_R_安野_extracted.json
#
# [92/555] 20250619_NTTイノベーティブデバイス_守屋様_V_上瀬_清水追記.xlsm
# Processing: 20250619_NTTイノベーティブデバイス_守屋様_V_上瀬_清水追記.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_NTTイノベーティブデバイス_守屋様_V_上瀬_清水追記_extracted.json
#
# [93/555] 20250701_北海道大学_岡本拓也_V_宮田.xlsm
# Processing: 20250701_北海道大学_岡本拓也_V_宮田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250701_北海道大学_岡本拓也_V_宮田_extracted.json
#
# [94/555] 20250604_AIST_石井紀代_R_清水.xlsm
# Processing: 20250604_AIST_石井紀代_R_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250604_AIST_石井紀代_R_清水_extracted.json
#
# [95/555] 20250624_徳島大学_髙山様_確度進捗_鎌田.xlsm
# Processing: 20250624_徳島大学_髙山様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250624_徳島大学_髙山様_確度進捗_鎌田_extracted.json
#
# [96/555] 20250624_京都大学_井上卓也先生_V_河合.xlsm
# Processing: 20250624_京都大学_井上卓也先生_V_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250624_京都大学_井上卓也先生_V_河合_extracted.json
#
# [97/555] 20250618_電気通信大学_平田 修造 先生_V_津江.xlsm
# Processing: 20250618_電気通信大学_平田 修造 先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250618_電気通信大学_平田 修造 先生_V_津江_extracted.json
#
# [98/555] 20250708_BLF_飯塚_R_安野.xlsm
# Processing: 20250708_BLF_飯塚_R_安野.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250708_BLF_飯塚_R_安野_extracted.json
#
# [99/555] 20250716_NTT先端集積デバイス研究所(厚木)_阿部真志_V_清水.xlsm
# Processing: 20250716_NTT先端集積デバイス研究所(厚木)_阿部真志_V_清水.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250716_NTT先端集積デバイス研究所(厚木)_阿部真志_V_清水_extracted.json
#
# [100/555] 20250728_NICT_鐵本智大_V_清水卓也.xlsm
# Processing: 20250728_NICT_鐵本智大_V_清水卓也.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250728_NICT_鐵本智大_V_清水卓也_extracted.json
#
# [101/555] 20250627_産業技術総合研究所_柏木様_V_宮田.xlsm
# Processing: 20250627_産業技術総合研究所_柏木様_V_宮田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250627_産業技術総合研究所_柏木様_V_宮田_extracted.json
#
# [102/555] 20250606_北海道大学_清水裕樹_V_清水.xlsm
# Processing: 20250606_北海道大学_清水裕樹_V_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_北海道大学_清水裕樹_V_清水_extracted.json
#
# [103/555] 20250620_NICT_和久井健太郎_V_清水（20250623）.xlsm
# Processing: 20250620_NICT_和久井健太郎_V_清水（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250620_NICT_和久井健太郎_V_清水（20250623）_extracted.json
#
# [104/555] 20250722_横浜国立大学_馬場俊彦_V_山下真弘.xlsm
# Processing: 20250722_横浜国立大学_馬場俊彦_V_山下真弘.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250722_横浜国立大学_馬場俊彦_V_山下真弘_extracted.json
#
# [105/555] 20250617_名古屋工業大学_菅野先生_V_河合.xlsm
# Processing: 20250617_名古屋工業大学_菅野先生_V_河合.xlsm (営業 (フォーマット案_営業本部）, 81x21)
# 81
# 💾 Saved: outputs/20250617_名古屋工業大学_菅野先生_V_河合_extracted.json
#
# [106/555] 20250725_NTTイノベーティブデバイス_吉村様_V_清水（20250723）.xlsm
# Processing: 20250725_NTTイノベーティブデバイス_吉村様_V_清水（20250723）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250725_NTTイノベーティブデバイス_吉村様_V_清水（20250723）_extracted.json
#
# [107/555] 20250606_産総研（AIST）_野田康平_V・確度進捗_安野.xlsm
# Processing: 20250606_産総研（AIST）_野田康平_V・確度進捗_安野.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_産総研（AIST）_野田康平_V・確度進捗_安野_extracted.json
#
# [108/555] 20250605_千歳科学技術大_吉本先生_V_清水.xlsm
# Processing: 20250605_千歳科学技術大_吉本先生_V_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250605_千歳科学技術大_吉本先生_V_清水_extracted.json
#
# [109/555] 20250724_NTT未ね研_濱岡福太郎_V_大久保.xlsm
# Processing: 20250724_NTT未ね研_濱岡福太郎_V_大久保.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_NTT未ね研_濱岡福太郎_V_大久保_extracted.json
#
# [110/555] 20250704_徳島大学_久世先生_確度進捗_鎌田.xlsm
# Processing: 20250704_徳島大学_久世先生_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250704_徳島大学_久世先生_確度進捗_鎌田_extracted.json
#
# [111/555] 20250725_日本電子計算株式会社_竹内雅浩_R_杉山啓太.xlsm
# Processing: 20250725_日本電子計算株式会社_竹内雅浩_R_杉山啓太.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250725_日本電子計算株式会社_竹内雅浩_R_杉山啓太_extracted.json
#
# [112/555] 20250722_ミライズテクノロジーズ_神谷様_V_河合.xlsm
# Processing: 20250722_ミライズテクノロジーズ_神谷様_V_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250722_ミライズテクノロジーズ_神谷様_V_河合_extracted.json
#
# [113/555] 20250604_Polatis_Wally_R_大久保.xlsm
# Processing: 20250604_Polatis_Wally_R_大久保.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250604_Polatis_Wally_R_大久保_extracted.json
#
# [114/555] 20250612_東京科学大学_片瀬 貴義 先生_V_津江.xlsm
# Processing: 20250612_東京科学大学_片瀬 貴義 先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_東京科学大学_片瀬 貴義 先生_V_津江_extracted.json
#
# [115/555] 20250711_宇都宮大学_山本先生_確度進捗_鎌田.xlsm
# Processing: 20250711_宇都宮大学_山本先生_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250711_宇都宮大学_山本先生_確度進捗_鎌田_extracted.json
#
# [116/555] 20250613_NTTイノベーティブデバイス_守屋様_確度進捗_上瀬.xlsm
# Processing: 20250613_NTTイノベーティブデバイス_守屋様_確度進捗_上瀬.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250613_NTTイノベーティブデバイス_守屋様_確度進捗_上瀬_extracted.json
#
# [117/555] 20250702_TOMEY_山成様_V_河合.xlsm
# Processing: 20250702_TOMEY_山成様_V_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250702_TOMEY_山成様_V_河合_extracted.json
#
# [118/555] 20250701_京都大学_高橋先生_V_河合.xlsm
# Processing: 20250701_京都大学_高橋先生_V_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250701_京都大学_高橋先生_V_河合_extracted.json
#
# [119/555] 20250724_株式会社中海テレビ放送_黒田隆之_V_ 杉山啓太.xlsm
# Processing: 20250724_株式会社中海テレビ放送_黒田隆之_V_ 杉山啓太.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_株式会社中海テレビ放送_黒田隆之_V_ 杉山啓太_extracted.json
#
# [120/555] 20250620_GVM_エノク様_R・確度進捗_叶浩司.xlsm
# Processing: 20250620_GVM_エノク様_R・確度進捗_叶浩司.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250620_GVM_エノク様_R・確度進捗_叶浩司_extracted.json
#
# [121/555] 20250704_東京大学_田畑仁先生_V_津江.xlsm
# Processing: 20250704_東京大学_田畑仁先生_V_津江.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250704_東京大学_田畑仁先生_V_津江_extracted.json
#
# [122/555] 20250627_AIST_村井 俊哉_V_清水卓也.xlsm
# Processing: 20250627_AIST_村井 俊哉_V_清水卓也.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250627_AIST_村井 俊哉_V_清水卓也_extracted.json
#
# [123/555] 20250708_ユニオンツール_齋藤様_V_久保寺（20250623）.xlsm
# Processing: 20250708_ユニオンツール_齋藤様_V_久保寺（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250708_ユニオンツール_齋藤様_V_久保寺（20250623）_extracted.json
#
# [124/555] 20250620_NICT_小田祥一朗_V_清水（20250623）.xlsm
# Processing: 20250620_NICT_小田祥一朗_V_清水（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250620_NICT_小田祥一朗_V_清水（20250623）_extracted.json
#
# [125/555] 20250724_浜ホト_瀬上_V_安野.xlsm
# Processing: 20250724_浜ホト_瀬上_V_安野.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_浜ホト_瀬上_V_安野_extracted.json
#
# [126/555] 20250716_NTT物性科学基礎研究所(厚木)_池田幸平_V_清水.xlsm
# Processing: 20250716_NTT物性科学基礎研究所(厚木)_池田幸平_V_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250716_NTT物性科学基礎研究所(厚木)_池田幸平_V_清水_extracted.json
#
# [127/555] 20250623_菱光社_木村様_R_河合.xlsm
# Processing: 20250623_菱光社_木村様_R_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250623_菱光社_木村様_R_河合_extracted.json
#
# [128/555] 20250619_国立天文台_石井峻_V_大久保.xlsm
# Processing: 20250619_国立天文台_石井峻_V_大久保.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_国立天文台_石井峻_V_大久保_extracted.json
#
# [129/555] 20250715_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm
# Processing: 20250715_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250715_高輝度光科学研究センター_松原様_確度進捗_鎌田_extracted.json
#
# [130/555] 20250605_富士通_田中伸介_V_大久保.xlsm
# Processing: 20250605_富士通_田中伸介_V_大久保.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250605_富士通_田中伸介_V_大久保_extracted.json
#
# [131/555] 20250604_阪大ILE_藤岡_T_加賀.xlsm
# Processing: 20250604_阪大ILE_藤岡_T_加賀.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250604_阪大ILE_藤岡_T_加賀_extracted.json
#
# [132/555] 20250606_四国総合研究所_大井様_確度進捗_鎌田.xlsm
# Processing: 20250606_四国総合研究所_大井様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_四国総合研究所_大井様_確度進捗_鎌田_extracted.json
#
# [133/555] 20250708_ミハル通信_筑葉拓生_V_大久保.xlsm
# Processing: 20250708_ミハル通信_筑葉拓生_V_大久保.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250708_ミハル通信_筑葉拓生_V_大久保_extracted.json
#
# [134/555] 20250626_Supership_芹澤_R_大久保.xlsm
# Processing: 20250626_Supership_芹澤_R_大久保.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250626_Supership_芹澤_R_大久保_extracted.json
#
# [135/555] 20250724_ソニー_土岡弘明_V_清水.xlsm
# Processing: 20250724_ソニー_土岡弘明_V_清水.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_ソニー_土岡弘明_V_清水_extracted.json
#
# [136/555] 20250725_NTT_大本_V_安野.xlsm
# Processing: 20250725_NTT_大本_V_安野.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250725_NTT_大本_V_安野_extracted.json
#
# [137/555] 20250602_DMM_大城様_確度進捗_大久保.xlsm
# Processing: 20250602_DMM_大城様_確度進捗_大久保.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250602_DMM_大城様_確度進捗_大久保_extracted.json
#
# [138/555] 20250707_長岡技術科学大学_南部様_V_久保寺（20250623）.xlsm
# Processing: 20250707_長岡技術科学大学_南部様_V_久保寺（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250707_長岡技術科学大学_南部様_V_久保寺（20250623）_extracted.json
#
# [139/555] 20250703_大阪大学_天野先生_V_河合.xlsm
# Processing: 20250703_大阪大学_天野先生_V_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250703_大阪大学_天野先生_V_河合_extracted.json
#
# [140/555] 20250725_東京エレクトロンデバイス_今井洋介_V_山下真弘.xlsm
# Processing: 20250725_東京エレクトロンデバイス_今井洋介_V_山下真弘.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250725_東京エレクトロンデバイス_今井洋介_V_山下真弘_extracted.json
#
# [141/555] 20250711_電気通信大学_小池卓二先生_V_津江.xlsm
# Processing: 20250711_電気通信大学_小池卓二先生_V_津江.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250711_電気通信大学_小池卓二先生_V_津江_extracted.json
#
# [142/555] 20250613_オムロンー横井忠正様_R_山下真弘.xlsm
# Processing: 20250613_オムロンー横井忠正様_R_山下真弘.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250613_オムロンー横井忠正様_R_山下真弘_extracted.json
#
# [143/555] 20250616_宇都宮大学_山本様_確度進捗_鎌田.xlsm
# Processing: 20250616_宇都宮大学_山本様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250616_宇都宮大学_山本様_確度進捗_鎌田_extracted.json
#
# [144/555] 20250610_電気通信大学_小池 卓二 先生_V_津江.xlsm
# Processing: 20250610_電気通信大学_小池 卓二 先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250610_電気通信大学_小池 卓二 先生_V_津江_extracted.json
#
# [145/555] 20250717_アトライズヨドガワ_宮下様・植栗様_V_上瀬（20250623）.xlsm
# Processing: 20250717_アトライズヨドガワ_宮下様・植栗様_V_上瀬（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250717_アトライズヨドガワ_宮下様・植栗様_V_上瀬（20250623）_extracted.json
#
# [146/555] 20250626_NTT IOWNプロダクトセンタ_鬼頭岳之_V_大久保.xlsm
# Processing: 20250626_NTT IOWNプロダクトセンタ_鬼頭岳之_V_大久保.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250626_NTT IOWNプロダクトセンタ_鬼頭岳之_V_大久保_extracted.json
#
# [147/555] 20250729_東京大学_杉松治美（川口 特任教授）_V_津江.xlsm
# Processing: 20250729_東京大学_杉松治美（川口 特任教授）_V_津江.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250729_東京大学_杉松治美（川口 特任教授）_V_津江_extracted.json
#
# [148/555] 20250612_阪大ILE _重森_V_加賀.xlsm
# Processing: 20250612_阪大ILE _重森_V_加賀.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_阪大ILE _重森_V_加賀_extracted.json
#
# [149/555] 20250703_NTT_野村啓仁_R_大久保.xlsm
# Processing: 20250703_NTT_野村啓仁_R_大久保.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250703_NTT_野村啓仁_R_大久保_extracted.json
#
# [150/555] 20250606_徳島大学_髙山様_確度進捗_鎌田.xlsm
# Processing: 20250606_徳島大学_髙山様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_徳島大学_髙山様_確度進捗_鎌田_extracted.json
#
# [151/555] 20250701_NTTイノベーティブデバイス_高橋様_V_上瀬（20250623）.xlsm
# Processing: 20250701_NTTイノベーティブデバイス_高橋様_V_上瀬（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250701_NTTイノベーティブデバイス_高橋様_V_上瀬（20250623）_extracted.json
#
# [152/555] 20250701_北海道大学_田口敦清_V_宮田.xlsm
# Processing: 20250701_北海道大学_田口敦清_V_宮田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250701_北海道大学_田口敦清_V_宮田_extracted.json
#
# [153/555] 20250709_日星電気_中道様_V_河合.xlsm
# Processing: 20250709_日星電気_中道様_V_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250709_日星電気_中道様_V_河合_extracted.json
#
# [154/555] 20250701_アイステーシス_冨山_R_安野.xlsm
# Processing: 20250701_アイステーシス_冨山_R_安野.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250701_アイステーシス_冨山_R_安野_extracted.json
#
# [155/555] 20250627_東洋電機_服部様_V_河合.xlsm
# Processing: 20250627_東洋電機_服部様_V_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250627_東洋電機_服部様_V_河合_extracted.json
#
# [156/555] 20250624_santec_三國_V_安野.xlsm
# Processing: 20250624_santec_三國_V_安野.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250624_santec_三國_V_安野_extracted.json
#
# [157/555] 20250716_東京大学_坂上先生_V確度進捗_宮田.xlsm
# Processing: 20250716_東京大学_坂上先生_V確度進捗_宮田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250716_東京大学_坂上先生_V確度進捗_宮田_extracted.json
#
# [158/555] 20250610_徳島大学_髙山様_確度進捗_鎌田.xlsm
# Processing: 20250610_徳島大学_髙山様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250610_徳島大学_髙山様_確度進捗_鎌田_extracted.json
#
# [159/555] 20250624_ニコン_三瀧正俊_V_山下真弘.xlsm
# Processing: 20250624_ニコン_三瀧正俊_V_山下真弘.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250624_ニコン_三瀧正俊_V_山下真弘_extracted.json
#
# [160/555] 20250603_NIC_山内英樹_確度進捗_大久保.xlsm
# Processing: 20250603_NIC_山内英樹_確度進捗_大久保.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250603_NIC_山内英樹_確度進捗_大久保_extracted.json
#
# [161/555] 20250619_NTTイノベーティブデバイス_今野様_V_上瀬_清水追記.xlsm
# Processing: 20250619_NTTイノベーティブデバイス_今野様_V_上瀬_清水追記.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_NTTイノベーティブデバイス_今野様_V_上瀬_清水追記_extracted.json
#
# [162/555] 20250724_JPIX_斎藤久美_V_ 杉山啓太.xlsm
# Processing: 20250724_JPIX_斎藤久美_V_ 杉山啓太.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_JPIX_斎藤久美_V_ 杉山啓太_extracted.json
#
# [163/555] 20250724_京都大学_長崎先生_V_河合（20250723）.xlsm
# Processing: 20250724_京都大学_長崎先生_V_河合（20250723）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_京都大学_長崎先生_V_河合（20250723）_extracted.json
#
# [164/555] 20250729_東京大学_町田友樹先生_V_津江.xlsm
# Processing: 20250729_東京大学_町田友樹先生_V_津江.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250729_東京大学_町田友樹先生_V_津江_extracted.json
#
# [165/555] 20250609_NTT東日本_小田友和_M_大久保.xlsm
# Processing: 20250609_NTT東日本_小田友和_M_大久保.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250609_NTT東日本_小田友和_M_大久保_extracted.json
#
# [166/555] .~20250602_NEC_中村康平_確度進捗_大久保.xlsm
# ❌ Error: File is not a zip file
# 💾 Saved: outputs/.~20250602_NEC_中村康平_確度進捗_大久保_extracted.json
#
# [167/555] 20250602_徳島大学_檜垣様_確度進捗_セブンシックス鎌田.xlsm
# Processing: 20250602_徳島大学_檜垣様_確度進捗_セブンシックス鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250602_徳島大学_檜垣様_確度進捗_セブンシックス鎌田_extracted.json
#
# [168/555] 20250702_四国総合研究所_大井様_確度進捗_鎌田.xlsm
# Processing: 20250702_四国総合研究所_大井様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250702_四国総合研究所_大井様_確度進捗_鎌田_extracted.json
#
# [169/555] 20250704_NTTイノベーティブデバイス_小澤様_V_上瀬（20250623）.xlsm
# Processing: 20250704_NTTイノベーティブデバイス_小澤様_V_上瀬（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250704_NTTイノベーティブデバイス_小澤様_V_上瀬（20250623）_extracted.json
#
# [170/555] 20250704_東京大学_岡本博_V_山下真弘.xlsm
# Processing: 20250704_東京大学_岡本博_V_山下真弘.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250704_東京大学_岡本博_V_山下真弘_extracted.json
#
# [171/555] 20250605_徳島大学_檜垣様_確度進捗_鎌田.xlsm
# Processing: 20250605_徳島大学_檜垣様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250605_徳島大学_檜垣様_確度進捗_鎌田_extracted.json
#
# [172/555] 20250724_日本デジタル配信株式会社_浦屋好男_V_ 杉山啓太.xlsm
# Processing: 20250724_日本デジタル配信株式会社_浦屋好男_V_ 杉山啓太.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_日本デジタル配信株式会社_浦屋好男_V_ 杉山啓太_extracted.json
#
# [173/555] 20250618_NTT厚木研究所_野原様_V_清水.xlsm
# Processing: 20250618_NTT厚木研究所_野原様_V_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250618_NTT厚木研究所_野原様_V_清水_extracted.json
#
# [174/555] 20250703_タマリ_榊田_V_安野.xlsm
# Processing: 20250703_タマリ_榊田_V_安野.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250703_タマリ_榊田_V_安野_extracted.json
#
# [175/555] 20250630_四国総合研究所_大井様_確度進捗_鎌田.xlsm
# Processing: 20250630_四国総合研究所_大井様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250630_四国総合研究所_大井様_確度進捗_鎌田_extracted.json
#
# [176/555] 20250702_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm
# Processing: 20250702_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250702_高輝度光科学研究センター_松原様_確度進捗_鎌田_extracted.json
#
# [177/555] 20250624_京都大学_吉田先生_V_河合.xlsm
# Processing: 20250624_京都大学_吉田先生_V_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250624_京都大学_吉田先生_V_河合_extracted.json
#
# [178/555] 20250602_シンクランド株式会社_東條_確度進捗_津江.xlsm
# Processing: 20250602_シンクランド株式会社_東條_確度進捗_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250602_シンクランド株式会社_東條_確度進捗_津江_extracted.json
#
# [179/555] 20250606_産総研（AIST）_石井紀代_V_安野.xlsm
# Processing: 20250606_産総研（AIST）_石井紀代_V_安野.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_産総研（AIST）_石井紀代_V_安野_extracted.json
#
# [180/555] 20250602_徳島大学_矢野先生_確度進捗_セブンシックス鎌田.xlsm
# Processing: 20250602_徳島大学_矢野先生_確度進捗_セブンシックス鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250602_徳島大学_矢野先生_確度進捗_セブンシックス鎌田_extracted.json
#
# [181/555] 20250710_徳島大学_檜垣様_確度進捗_鎌田.xlsm
# Processing: 20250710_徳島大学_檜垣様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250710_徳島大学_檜垣様_確度進捗_鎌田_extracted.json
#
# [182/555] 20250619_JRWON株式会社_川端良昌様_V・確度進捗_叶浩司.xlsm
# Processing: 20250619_JRWON株式会社_川端良昌様_V・確度進捗_叶浩司.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_JRWON株式会社_川端良昌様_V・確度進捗_叶浩司_extracted.json
#
# [183/555] 20250711_徳島大学_安井先生_確度進捗_鎌田.xlsm
# Processing: 20250711_徳島大学_安井先生_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250711_徳島大学_安井先生_確度進捗_鎌田_extracted.json
#
# [184/555] 20250702_クアンテック_上瀧英郎_R_山下真弘.xlsm
# Processing: 20250702_クアンテック_上瀧英郎_R_山下真弘.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250702_クアンテック_上瀧英郎_R_山下真弘_extracted.json
#
# [185/555] 20250729_NTTデバイスクロステクノロジ厚木_草薙都巳_V_清水.xlsm
# Processing: 20250729_NTTデバイスクロステクノロジ厚木_草薙都巳_V_清水.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250729_NTTデバイスクロステクノロジ厚木_草薙都巳_V_清水_extracted.json
#
# [186/555] 20250624_東京農工大学ー田中洋介様_V_山下真弘.xlsm
# Processing: 20250624_東京農工大学ー田中洋介様_V_山下真弘.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250624_東京農工大学ー田中洋介様_V_山下真弘_extracted.json
#
# [187/555] 20250627_BlueLaserFusion合同会社_飯塚清太様_V_森田智教.xlsm
# Processing: 20250627_BlueLaserFusion合同会社_飯塚清太様_V_森田智教.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250627_BlueLaserFusion合同会社_飯塚清太様_V_森田智教_extracted.json
#
# [188/555] 20250605_浜松ホトニクス〈豊岡事業所〉ー_奈良康永_V_山下真弘.xlsm
# Processing: 20250605_浜松ホトニクス〈豊岡事業所〉ー_奈良康永_V_山下真弘.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250605_浜松ホトニクス〈豊岡事業所〉ー_奈良康永_V_山下真弘_extracted.json
#
# [189/555] 20250724_株式会社ナノコネクト_名合智洋_V_ 杉山啓太.xlsm
# Processing: 20250724_株式会社ナノコネクト_名合智洋_V_ 杉山啓太.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_株式会社ナノコネクト_名合智洋_V_ 杉山啓太_extracted.json
#
# [190/555] 20250612_GVM_エノク_V_杉山.xlsm
# Processing: 20250612_GVM_エノク_V_杉山.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_GVM_エノク_V_杉山_extracted.json
#
# [191/555] 20250701_ワイヤ・アンド・ワイヤレス_中山　巧三_R_叶杉山.xlsm
# Processing: 20250701_ワイヤ・アンド・ワイヤレス_中山　巧三_R_叶杉山.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250701_ワイヤ・アンド・ワイヤレス_中山　巧三_R_叶杉山_extracted.json
#
# [192/555] 20250704_Otnet_備瀬航_R_叶杉山.xlsm
# Processing: 20250704_Otnet_備瀬航_R_叶杉山.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250704_Otnet_備瀬航_R_叶杉山_extracted.json
#
# [193/555] 20250627_東京科学大学_中本高道先生_V_津江.xlsm
# Processing: 20250627_東京科学大学_中本高道先生_V_津江.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250627_東京科学大学_中本高道先生_V_津江_extracted.json
#
# [194/555] 20250723_高輝度光科学研究センター_松原様_確度進捗_鎌田（20250723）.xlsm
# Processing: 20250723_高輝度光科学研究センター_松原様_確度進捗_鎌田（20250723）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250723_高輝度光科学研究センター_松原様_確度進捗_鎌田（20250723）_extracted.json
#
# [195/555] 20250724_株式会社ＩＩＪエンジニアリング_橋本知絵里_V_ 杉山啓太.xlsm
# Processing: 20250724_株式会社ＩＩＪエンジニアリング_橋本知絵里_V_ 杉山啓太.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_株式会社ＩＩＪエンジニアリング_橋本知絵里_V_ 杉山啓太_extracted.json
#
# [196/555] 20250624_santec_堀口_V_安野.xlsm
# Processing: 20250624_santec_堀口_V_安野.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250624_santec_堀口_V_安野_extracted.json
#
# [197/555] 20250709_NTT-ATクリエイティブ_安藝様_確度進捗_鎌田.xlsm
# Processing: 20250709_NTT-ATクリエイティブ_安藝様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250709_NTT-ATクリエイティブ_安藝様_確度進捗_鎌田_extracted.json
#
# [198/555] 20250606_日本電気株式会社ー野口栄実様_案件進捗_山下真弘 -.xlsm
# Processing: 20250606_日本電気株式会社ー野口栄実様_案件進捗_山下真弘 -.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_日本電気株式会社ー野口栄実様_案件進捗_山下真弘 -_extracted.json
#
# [199/555] 20250602_NEC_中村康平_確度進捗_大久保.xlsm
# Processing: 20250602_NEC_中村康平_確度進捗_大久保.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250602_NEC_中村康平_確度進捗_大久保_extracted.json
#
# [200/555] 20250618_徳島大学_髙山様_確度進捗_鎌田.xlsm
# Processing: 20250618_徳島大学_髙山様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250618_徳島大学_髙山様_確度進捗_鎌田_extracted.json
#
# [201/555] 20250609_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm
# Processing: 20250609_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250609_高輝度光科学研究センター_松原様_確度進捗_鎌田_extracted.json
#
# [202/555] 20250729_東京大学_鈴木様_V確度進捗_宮田.xlsm
# Processing: 20250729_東京大学_鈴木様_V確度進捗_宮田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250729_東京大学_鈴木様_V確度進捗_宮田_extracted.json
#
# [203/555] 20250708_Blue Laser Fusion_小原様_確度進捗_鎌田.xlsm
# Processing: 20250708_Blue Laser Fusion_小原様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250708_Blue Laser Fusion_小原様_確度進捗_鎌田_extracted.json
#
# [204/555] 20250724_NTT_中島光雅_R_清水.xlsm
# Processing: 20250724_NTT_中島光雅_R_清水.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_NTT_中島光雅_R_清水_extracted.json
#
# [205/555] 20250620_大阪大学_深井先生_V_河合.xlsm
# Processing: 20250620_大阪大学_深井先生_V_河合.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250620_大阪大学_深井先生_V_河合_extracted.json
#
# [206/555] 20250724_浜ホト_海老原_V_安野.xlsm
# Processing: 20250724_浜ホト_海老原_V_安野.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_浜ホト_海老原_V_安野_extracted.json
#
# [207/555] 20250717_東京大学_田畑仁先生_V_津江.xlsm
# Processing: 20250717_東京大学_田畑仁先生_V_津江.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250717_東京大学_田畑仁先生_V_津江_extracted.json
#
# [208/555] 20250724_京都大学_廣理先生_V_河合（20250723）.xlsm
# Processing: 20250724_京都大学_廣理先生_V_河合（20250723）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_京都大学_廣理先生_V_河合（20250723）_extracted.json
#
# [209/555] 20250602_さくらインターネット株式会社_小椋様_R・確度進捗_叶浩司.xlsm
# Processing: 20250602_さくらインターネット株式会社_小椋様_R・確度進捗_叶浩司.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250602_さくらインターネット株式会社_小椋様_R・確度進捗_叶浩司_extracted.json
#
# [210/555] 20250611_MIND_岸浪康博_V_杉山.xlsm
# Processing: 20250611_MIND_岸浪康博_V_杉山.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250611_MIND_岸浪康博_V_杉山_extracted.json
#
# [211/555] 20250606_北海道大学_小林淳_V_森田.xlsm
# Processing: 20250606_北海道大学_小林淳_V_森田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_北海道大学_小林淳_V_森田_extracted.json
#
# [212/555] 20250722_兵庫県立大学_榎原先生_確度進捗_鎌田.xlsm
# Processing: 20250722_兵庫県立大学_榎原先生_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250722_兵庫県立大学_榎原先生_確度進捗_鎌田_extracted.json
#
# [213/555] 20250605_東京科学大学_西迫 貴志 先生_V_津江.xlsm
# Processing: 20250605_東京科学大学_西迫 貴志 先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250605_東京科学大学_西迫 貴志 先生_V_津江_extracted.json
#
# [214/555] 20250723_四国市総合研究所_大井様_鎌田（20250723）.xlsm
# Processing: 20250723_四国市総合研究所_大井様_鎌田（20250723）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250723_四国市総合研究所_大井様_鎌田（20250723）_extracted.json
#
# [215/555] 20250625_JVCケンウッド_太田朋佳_V_大久保.xlsm
# Processing: 20250625_JVCケンウッド_太田朋佳_V_大久保.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250625_JVCケンウッド_太田朋佳_V_大久保_extracted.json
#
# [216/555] 20250619_九大_三上裕也_V_安野.xlsm
# Processing: 20250619_九大_三上裕也_V_安野.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_九大_三上裕也_V_安野_extracted.json
#
# [217/555] 20250619_福岡大_大前宣昭_V_安野.xlsm
# Processing: 20250619_福岡大_大前宣昭_V_安野.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_福岡大_大前宣昭_V_安野_extracted.json
#
# [218/555] 20250714_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm
# Processing: 20250714_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250714_高輝度光科学研究センター_松原様_確度進捗_鎌田_extracted.json
#
# [219/555] .~20250602_DMM_大城様_確度進捗_大久保.xlsm
# ❌ Error: File is not a zip file
# 💾 Saved: outputs/.~20250602_DMM_大城様_確度進捗_大久保_extracted.json
#
# [220/555] 20250724_となみ衛星通信テレビ株式会社_新山優人_V_ 杉山啓太.xlsm
# Processing: 20250724_となみ衛星通信テレビ株式会社_新山優人_V_ 杉山啓太.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_となみ衛星通信テレビ株式会社_新山優人_V_ 杉山啓太_extracted.json
#
# [221/555] 20250627_Blue Laser Fusion_小原様_確度進捗_鎌田.xlsm
# Processing: 20250627_Blue Laser Fusion_小原様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250627_Blue Laser Fusion_小原様_確度進捗_鎌田_extracted.json
#
# [222/555] 20250624_京都大学_筒井先生_V_河合.xlsm
# Processing: 20250624_京都大学_筒井先生_V_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250624_京都大学_筒井先生_V_河合_extracted.json
#
# [223/555] 20250619_NTTイノベーティブデバイス_石川様・関様_V_上瀬_清水追記.xlsm
# Processing: 20250619_NTTイノベーティブデバイス_石川様・関様_V_上瀬_清水追記.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_NTTイノベーティブデバイス_石川様・関様_V_上瀬_清水追記_extracted.json
#
# [224/555] 20250612_宇都宮大学_山本様_確度進捗_鎌田.xlsm
# Processing: 20250612_宇都宮大学_山本様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_宇都宮大学_山本様_確度進捗_鎌田_extracted.json
#
# [225/555] 20250612_アイシン_須藤様_V_河合.xlsm
# Processing: 20250612_アイシン_須藤様_V_河合.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_アイシン_須藤様_V_河合_extracted.json
#
# [226/555] 20250603_三菱電機モビリティ_田形_T_加賀.xlsm
# Processing: 20250603_三菱電機モビリティ_田形_T_加賀.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250603_三菱電機モビリティ_田形_T_加賀_extracted.json
#
# [227/555] 20250612_santec_女鹿田直之_V_安野.xlsm
# Processing: 20250612_santec_女鹿田直之_V_安野.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_santec_女鹿田直之_V_安野_extracted.json
#
# [228/555] 20250716_NTTイノベーティブデバイス厚木_宮田和典_成木歩夢_V_清水.xlsm
# Processing: 20250716_NTTイノベーティブデバイス厚木_宮田和典_成木歩夢_V_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250716_NTTイノベーティブデバイス厚木_宮田和典_成木歩夢_V_清水_extracted.json
#
# [229/555] 20250604_パワーレーザー_加藤_T_加賀.xlsm
# Processing: 20250604_パワーレーザー_加藤_T_加賀.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250604_パワーレーザー_加藤_T_加賀_extracted.json
#
# [230/555] 20250718_四国総合研究所_大井様_確度進捗_鎌田.xlsm
# Processing: 20250718_四国総合研究所_大井様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250718_四国総合研究所_大井様_確度進捗_鎌田_extracted.json
#
# [231/555] 20250624_santec_井上_V_安野.xlsm
# Processing: 20250624_santec_井上_V_安野.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250624_santec_井上_V_安野_extracted.json
#
# [232/555] 20250701_北海道大学_橋谷田俊_V_宮田.xlsm
# Processing: 20250701_北海道大学_橋谷田俊_V_宮田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250701_北海道大学_橋谷田俊_V_宮田_extracted.json
#
# [233/555] 20250711_東京大学_渡辺健太郎 先生_V_津江.xlsm
# Processing: 20250711_東京大学_渡辺健太郎 先生_V_津江.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250711_東京大学_渡辺健太郎 先生_V_津江_extracted.json
#
# [234/555] 20250626_Orbital Lasers_渡邉様、草柳様_V_宮田.xlsm
# Processing: 20250626_Orbital Lasers_渡邉様、草柳様_V_宮田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250626_Orbital Lasers_渡邉様、草柳様_V_宮田_extracted.json
#
# [235/555] 20250612_徳島大学_髙山様_確度進捗_鎌田.xlsm
# Processing: 20250612_徳島大学_髙山様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_徳島大学_髙山様_確度進捗_鎌田_extracted.json
#
# [236/555] 20250611_アット東京_本郷将来_V_杉山.xlsm
# Processing: 20250611_アット東京_本郷将来_V_杉山.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250611_アット東京_本郷将来_V_杉山_extracted.json
#
# [237/555] 20250711_NTT_坂本_V_安野.xlsm
# Processing: 20250711_NTT_坂本_V_安野.xlsm (報告書, 88x21)
# 88
# 💾 Saved: outputs/20250711_NTT_坂本_V_安野_extracted.json
#
# [238/555] 20250718_NICT_宗正康_V_清水卓也.xlsm
# Processing: 20250718_NICT_宗正康_V_清水卓也.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250718_NICT_宗正康_V_清水卓也_extracted.json
#
# [239/555] 20250725_NTTイノベーティブデバイス_大山様・齊藤様_V_上瀬（20250723）.xlsm
# Processing: 20250725_NTTイノベーティブデバイス_大山様・齊藤様_V_上瀬（20250723）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250725_NTTイノベーティブデバイス_大山様・齊藤様_V_上瀬（20250723）_extracted.json
#
# [240/555] 20250717_ニレコ_長谷山様・ダニエル様・月崎様_V_上瀬（20250623）.xlsm
# Processing: 20250717_ニレコ_長谷山様・ダニエル様・月崎様_V_上瀬（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250717_ニレコ_長谷山様・ダニエル様・月崎様_V_上瀬（20250623）_extracted.json
#
# [241/555] 20250617_EX-Fusion_我妻_確度進捗_加賀.xlsm
# Processing: 20250617_EX-Fusion_我妻_確度進捗_加賀.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250617_EX-Fusion_我妻_確度進捗_加賀_extracted.json
#
# [242/555] 20250701_YTM_Yamamoto Kenta_V_Ohashi（20250623）.xlsm
# Processing: 20250701_YTM_Yamamoto Kenta_V_Ohashi（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250701_YTM_Yamamoto Kenta_V_Ohashi（20250623）_extracted.json
#
# [243/555] 20250729_NTT物性科学基礎研究所(厚木)_松山圭吾_V_清水.xlsm
# Processing: 20250729_NTT物性科学基礎研究所(厚木)_松山圭吾_V_清水.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250729_NTT物性科学基礎研究所(厚木)_松山圭吾_V_清水_extracted.json
#
# [244/555] 20250722_国立天文台_石井峻_R_大久保.xlsm
# Processing: 20250722_国立天文台_石井峻_R_大久保.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250722_国立天文台_石井峻_R_大久保_extracted.json
#
# [245/555] 20250709_ウシオ_横山_V_安野.xlsm
# Processing: 20250709_ウシオ_横山_V_安野.xlsm (報告書, 88x21)
# 88
# 💾 Saved: outputs/20250709_ウシオ_横山_V_安野_extracted.json
#
# [246/555] 20250624_santec_久能_V_安野.xlsm
# Processing: 20250624_santec_久能_V_安野.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250624_santec_久能_V_安野_extracted.json
#
# [247/555] 20250716_宇都宮大学_山本先生_確度進捗_鎌田.xlsm
# Processing: 20250716_宇都宮大学_山本先生_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250716_宇都宮大学_山本先生_確度進捗_鎌田_extracted.json
#
# [248/555] 20250606_Optotune_ChiWen_R_加賀.xlsm
# Processing: 20250606_Optotune_ChiWen_R_加賀.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_Optotune_ChiWen_R_加賀_extracted.json
#
# [249/555] 20250606_北海道大学_関川太郎_V_清水.xlsm
# Processing: 20250606_北海道大学_関川太郎_V_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_北海道大学_関川太郎_V_清水_extracted.json
#
# [250/555] 20250605_浜松ホトニクス〈中央研究所〉ー堀田和希_V_山下真弘.xlsm
# Processing: 20250605_浜松ホトニクス〈中央研究所〉ー堀田和希_V_山下真弘.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250605_浜松ホトニクス〈中央研究所〉ー堀田和希_V_山下真弘_extracted.json
#
# [251/555] 20250724_四国市総合研究所_大井様_鎌田（20250724）.xlsm
# Processing: 20250724_四国市総合研究所_大井様_鎌田（20250724）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_四国市総合研究所_大井様_鎌田（20250724）_extracted.json
#
# [252/555] 20250709_光産業創成大学院大学_林先生_V_河合.xlsm
# Processing: 20250709_光産業創成大学院大学_林先生_V_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250709_光産業創成大学院大学_林先生_V_河合_extracted.json
#
# [253/555] 20250616_埼玉工業大学_古川 靖_確度進捗_津江.xlsm
# Processing: 20250616_埼玉工業大学_古川 靖_確度進捗_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250616_埼玉工業大学_古川 靖_確度進捗_津江_extracted.json
#
# [254/555] 20250716_NTTイノベーティブデバイス(厚木)_土居芳行_V_清水.xlsm
# Processing: 20250716_NTTイノベーティブデバイス(厚木)_土居芳行_V_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250716_NTTイノベーティブデバイス(厚木)_土居芳行_V_清水_extracted.json
#
# [255/555] 20250709_アルテリアネットワークス_荒井伸治_R_大久保.xlsm
# Processing: 20250709_アルテリアネットワークス_荒井伸治_R_大久保.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250709_アルテリアネットワークス_荒井伸治_R_大久保_extracted.json
#
# [256/555] 20250725_産業技術総合研究所_大久保章_V・確度進捗_宮田.xlsm
# Processing: 20250725_産業技術総合研究所_大久保章_V・確度進捗_宮田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250725_産業技術総合研究所_大久保章_V・確度進捗_宮田_extracted.json
#
# [257/555] 20250724_東京大学_牛島一朗先生_V_津江.xlsm
# Processing: 20250724_東京大学_牛島一朗先生_V_津江.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_東京大学_牛島一朗先生_V_津江_extracted.json
#
# [258/555] 20250725_四国市総合研究所_大井様_鎌田（20250725）.xlsm
# Processing: 20250725_四国市総合研究所_大井様_鎌田（20250725）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250725_四国市総合研究所_大井様_鎌田（20250725）_extracted.json
#
# [259/555] 20250603_ディスコ_石塚_G_久保寺.xlsm
# Processing: 20250603_ディスコ_石塚_G_久保寺.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250603_ディスコ_石塚_G_久保寺_extracted.json
#
# [260/555] 20250619_電気通信大学_大川 富雄 先生_V_津江.xlsm
# Processing: 20250619_電気通信大学_大川 富雄 先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_電気通信大学_大川 富雄 先生_V_津江_extracted.json
#
# [261/555] 20250711_オムロン_種野篤_V_山下真弘.xlsm
# Processing: 20250711_オムロン_種野篤_V_山下真弘.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250711_オムロン_種野篤_V_山下真弘_extracted.json
#
# [262/555] 20250725_NTT_早川_V_安野.xlsm
# Processing: 20250725_NTT_早川_V_安野.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250725_NTT_早川_V_安野_extracted.json
#
# [263/555] 20250603_NTT未ね研_高橋様_確度進捗_大久保.xlsm
# Processing: 20250603_NTT未ね研_高橋様_確度進捗_大久保.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250603_NTT未ね研_高橋様_確度進捗_大久保_extracted.json
#
# [264/555] 20250612_santec_姚達_V_安野.xlsm
# Processing: 20250612_santec_姚達_V_安野.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_santec_姚達_V_安野_extracted.json
#
# [265/555] 20250603_パワーレーザー_加藤_T_加賀.xlsm
# Processing: 20250603_パワーレーザー_加藤_T_加賀.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250603_パワーレーザー_加藤_T_加賀_extracted.json
#
# [266/555] 20250612_東京科学大学_阿尻 大雅 先生_V_津江.xlsm
# Processing: 20250612_東京科学大学_阿尻 大雅 先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_東京科学大学_阿尻 大雅 先生_V_津江_extracted.json
#
# [267/555] 20250702_千歳科学技術大学_梅村信弘_V_清水卓也.xlsm
# Processing: 20250702_千歳科学技術大学_梅村信弘_V_清水卓也.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250702_千歳科学技術大学_梅村信弘_V_清水卓也_extracted.json
#
# [268/555] 20250717_ダンロップゴルフクラブ_地上清隆_V_山下真弘.xlsm
# Processing: 20250717_ダンロップゴルフクラブ_地上清隆_V_山下真弘.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250717_ダンロップゴルフクラブ_地上清隆_V_山下真弘_extracted.json
#
# [269/555] 20250617_アドバンテスト研究所_塩田和教_山下真弘.xlsm
# Processing: 20250617_アドバンテスト研究所_塩田和教_山下真弘.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250617_アドバンテスト研究所_塩田和教_山下真弘_extracted.json
#
# [270/555] 20250717_広島大学_八野先生_R_河合.xlsm
# Processing: 20250717_広島大学_八野先生_R_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250717_広島大学_八野先生_R_河合_extracted.json
#
# [271/555] 20250619_NTT NIC_山本宏_V_大久保.xlsm
# Processing: 20250619_NTT NIC_山本宏_V_大久保.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_NTT NIC_山本宏_V_大久保_extracted.json
#
# [272/555] 20250627_産業技術総合研究所_橋口様_V_宮田.xlsm
# Processing: 20250627_産業技術総合研究所_橋口様_V_宮田.xlsm (報告書, 97x21)
# 97
# ...
# 97
# 💾 Saved: outputs/20250625_東京大学_李 敏赫 先生_V_津江_extracted.json
#
# [467/555] 20250625_NTTイノベーティブデバイス_中村様_V_上瀬（20250623）.xlsm
# Processing: 20250625_NTTイノベーティブデバイス_中村様_V_上瀬（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250625_NTTイノベーティブデバイス_中村様_V_上瀬（20250623）_extracted.json
#
# [468/555] 20250619_SYNOVAジャパン_高野_R_久保寺.xlsm
# Processing: 20250619_SYNOVAジャパン_高野_R_久保寺.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_SYNOVAジャパン_高野_R_久保寺_extracted.json
#
# [469/555] 20250612_Nikon_Cho_V_Ohashi.xlsm
# Processing: 20250612_Nikon_Cho_V_Ohashi.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_Nikon_Cho_V_Ohashi_extracted.json
#
# [470/555] 20250604_東京科学大学_相良 剛光先生_V_津江.xlsm
# Processing: 20250604_東京科学大学_相良 剛光先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250604_東京科学大学_相良 剛光先生_V_津江_extracted.json
#
# [471/555] 20250707_東京計器株式会社_浦野真吾_meil_津江.xlsm
# Processing: 20250707_東京計器株式会社_浦野真吾_meil_津江.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250707_東京計器株式会社_浦野真吾_meil_津江_extracted.json
#
# [472/555] 20250603_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm
# Processing: 20250603_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250603_高輝度光科学研究センター_松原様_確度進捗_鎌田_extracted.json
#
# [473/555] 20250612_パワーレーザー_加藤_V_加賀.xlsm
# Processing: 20250612_パワーレーザー_加藤_V_加賀.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_パワーレーザー_加藤_V_加賀_extracted.json
#
# [474/555] 20250619_NTTイノベーティブデバイス_清水様_V_上瀬_清水追記.xlsm
# Processing: 20250619_NTTイノベーティブデバイス_清水様_V_上瀬_清水追記.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_NTTイノベーティブデバイス_清水様_V_上瀬_清水追記_extracted.json
#
# [475/555] 20250703_NICT_北村光雄_V_清水卓也.xlsm
# Processing: 20250703_NICT_北村光雄_V_清水卓也.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250703_NICT_北村光雄_V_清水卓也_extracted.json
#
# [476/555] 20250709_東京大学_種村拓夫 先生_V_津江.xlsm
# Processing: 20250709_東京大学_種村拓夫 先生_V_津江.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250709_東京大学_種村拓夫 先生_V_津江_extracted.json
#
# [477/555] 20250620_大阪大学_髙原先生_V_河合.xlsm
# Processing: 20250620_大阪大学_髙原先生_V_河合.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250620_大阪大学_髙原先生_V_河合_extracted.json
#
# [478/555] 20250603_NTT未ね研_川合晃_確度進捗_大久保.xlsm
# Processing: 20250603_NTT未ね研_川合晃_確度進捗_大久保.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250603_NTT未ね研_川合晃_確度進捗_大久保_extracted.json
#
# [479/555] 20250701_NTTイノベーティブデバイス_黒澤様_V_上瀬（20250623）.xlsm
# Processing: 20250701_NTTイノベーティブデバイス_黒澤様_V_上瀬（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250701_NTTイノベーティブデバイス_黒澤様_V_上瀬（20250623）_extracted.json
#
# [480/555] 20250717_宇都宮大学_山本先生_確度進捗_鎌田.xlsm
# Processing: 20250717_宇都宮大学_山本先生_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250717_宇都宮大学_山本先生_確度進捗_鎌田_extracted.json
#
# [481/555] 20250724_浜ホト_藤本_V_安野.xlsm
# Processing: 20250724_浜ホト_藤本_V_安野.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_浜ホト_藤本_V_安野_extracted.json
#
# [482/555] 20250606_産総研（AIST）_柏木謙_V_安野.xlsm
# Processing: 20250606_産総研（AIST）_柏木謙_V_安野.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_産総研（AIST）_柏木謙_V_安野_extracted.json
#
# [483/555] 20250703_大阪大学_馬越先生_V_河合.xlsm
# Processing: 20250703_大阪大学_馬越先生_V_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250703_大阪大学_馬越先生_V_河合_extracted.json
#
# [484/555] 20250604_NICT_和久井健太郎_V_清水.xlsm
# Processing: 20250604_NICT_和久井健太郎_V_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250604_NICT_和久井健太郎_V_清水_extracted.json
#
# [485/555] 20250605_ディスコ_朝日様_V_久保寺.xlsm
# Processing: 20250605_ディスコ_朝日様_V_久保寺.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250605_ディスコ_朝日様_V_久保寺_extracted.json
#
# [486/555] 20250606_北海道大学_山根啓作_V_清水.xlsm
# Processing: 20250606_北海道大学_山根啓作_V_清水.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_北海道大学_山根啓作_V_清水_extracted.json
#
# [487/555] 20250604_東京科学大学_八島 正知先生_V_津江.xlsm
# Processing: 20250604_東京科学大学_八島 正知先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250604_東京科学大学_八島 正知先生_V_津江_extracted.json
#
# [488/555] 20250617_徳島大学_安井様_確度進捗_鎌田.xlsm
# Processing: 20250617_徳島大学_安井様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250617_徳島大学_安井様_確度進捗_鎌田_extracted.json
#
# [489/555] 20250718_宇都宮大学_山本先生_確度進捗_鎌田.xlsm
# Processing: 20250718_宇都宮大学_山本先生_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250718_宇都宮大学_山本先生_確度進捗_鎌田_extracted.json
#
# [490/555] 20250701_Blue Laser Fusion_小原様_確度進捗_鎌田.xlsm
# Processing: 20250701_Blue Laser Fusion_小原様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250701_Blue Laser Fusion_小原様_確度進捗_鎌田_extracted.json
#
# [491/555] 20250611_徳島大学_髙山様_確度進捗_鎌田.xlsm
# Processing: 20250611_徳島大学_髙山様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250611_徳島大学_髙山様_確度進捗_鎌田_extracted.json
#
# [492/555] 20250708_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm
# Processing: 20250708_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250708_高輝度光科学研究センター_松原様_確度進捗_鎌田_extracted.json
#
# [493/555] 20250626_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm
# Processing: 20250626_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250626_高輝度光科学研究センター_松原様_確度進捗_鎌田_extracted.json
#
# [494/555] 20250613__アイテック阪急阪神_秋山_R_杉山.xlsm
# Processing: 20250613__アイテック阪急阪神_秋山_R_杉山.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250613__アイテック阪急阪神_秋山_R_杉山_extracted.json
#
# [495/555] 20250704_NTTイノベーティブデバイス_高橋様・坂本様_V_上瀬（20250623）.xlsm
# Processing: 20250704_NTTイノベーティブデバイス_高橋様・坂本様_V_上瀬（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250704_NTTイノベーティブデバイス_高橋様・坂本様_V_上瀬（20250623）_extracted.json
#
# [496/555] 20250619_福岡大_高橋忠宏_V_安野.xlsm
# Processing: 20250619_福岡大_高橋忠宏_V_安野.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_福岡大_高橋忠宏_V_安野_extracted.json
#
# [497/555] 20250724_東京大学_千足昇平先生_V_津江.xlsm
# Processing: 20250724_東京大学_千足昇平先生_V_津江.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_東京大学_千足昇平先生_V_津江_extracted.json
#
# [498/555] 20250724_オリンパス_嶋本篤義_R・確度進捗_宮田.xlsm
# Processing: 20250724_オリンパス_嶋本篤義_R・確度進捗_宮田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_オリンパス_嶋本篤義_R・確度進捗_宮田_extracted.json
#
# [499/555] 20250603_東京大学_窪 秀利 先生_V_津江.xlsm
# Processing: 20250603_東京大学_窪 秀利 先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250603_東京大学_窪 秀利 先生_V_津江_extracted.json
#
# [500/555] 20250707_長岡技術科学大学_鵜沼様_V_久保寺（20250623）.xlsm
# Processing: 20250707_長岡技術科学大学_鵜沼様_V_久保寺（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250707_長岡技術科学大学_鵜沼様_V_久保寺（20250623）_extracted.json
#
# [501/555] 20250729_阪大ILE_藤岡 高橋_TOW 戸川_V_加賀.xlsm
# Processing: 20250729_阪大ILE_藤岡 高橋_TOW 戸川_V_加賀.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250729_阪大ILE_藤岡 高橋_TOW 戸川_V_加賀_extracted.json
#
# [502/555] 20250707_長岡技術科学大学_加藤様_V_久保寺（20250623）.xlsm
# Processing: 20250707_長岡技術科学大学_加藤様_V_久保寺（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250707_長岡技術科学大学_加藤様_V_久保寺（20250623）_extracted.json
#
# [503/555] 20250707_長岡技術科学大学_江様_V_久保寺（20250623）.xlsm
# Processing: 20250707_長岡技術科学大学_江様_V_久保寺（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250707_長岡技術科学大学_江様_V_久保寺（20250623）_extracted.json
#
# [504/555] 20250723_東京科学大学_西山伸彦先生_mail_津江.xlsm
# Processing: 20250723_東京科学大学_西山伸彦先生_mail_津江.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250723_東京科学大学_西山伸彦先生_mail_津江_extracted.json
#
# [505/555] 20250626_伊藤電機_勝田_V_安野.xlsm
# Processing: 20250626_伊藤電機_勝田_V_安野.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250626_伊藤電機_勝田_V_安野_extracted.json
#
# [506/555] 20250605_浜松ホトニクス〈都田事業所〉ー瀬上英明_V_山下真弘.xlsm
# Processing: 20250605_浜松ホトニクス〈都田事業所〉ー瀬上英明_V_山下真弘.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250605_浜松ホトニクス〈都田事業所〉ー瀬上英明_V_山下真弘_extracted.json
#
# [507/555] 20250724_浜ホト_佐藤_V_安野.xlsm
# Processing: 20250724_浜ホト_佐藤_V_安野.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_浜ホト_佐藤_V_安野_extracted.json
#
# [508/555] 20250604_四国総合研究所_大井様_確度進捗_鎌田.xlsm
# Processing: 20250604_四国総合研究所_大井様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250604_四国総合研究所_大井様_確度進捗_鎌田_extracted.json
#
# [509/555] 20250715_名古屋大学_西澤先生_V_河合.xlsm
# Processing: 20250715_名古屋大学_西澤先生_V_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250715_名古屋大学_西澤先生_V_河合_extracted.json
#
# [510/555] 20250620_大阪大学_五月女先生_V_河合.xlsm
# Processing: 20250620_大阪大学_五月女先生_V_河合.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250620_大阪大学_五月女先生_V_河合_extracted.json
#
# [511/555] 20250724_ディスコ_中本_V_久保寺.xlsm
# Processing: 20250724_ディスコ_中本_V_久保寺.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_ディスコ_中本_V_久保寺_extracted.json
#
# [512/555] 20250605_双日テック_増田陽_R_大久保.xlsm
# Processing: 20250605_双日テック_増田陽_R_大久保.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250605_双日テック_増田陽_R_大久保_extracted.json
#
# [513/555] 20250703_NICT_Amalina Ibrahim_V_清水卓也.xlsm
# Processing: 20250703_NICT_Amalina Ibrahim_V_清水卓也.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250703_NICT_Amalina Ibrahim_V_清水卓也_extracted.json
#
# [514/555] 20250626_理化学研究所_沖野様_V_宮田.xlsm
# Processing: 20250626_理化学研究所_沖野様_V_宮田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250626_理化学研究所_沖野様_V_宮田_extracted.json
#
# [515/555] 20250610_近鉄ケーブルネットワーク株式会社_古川様_R・確度進捗_叶浩司.xlsm
# Processing: 20250610_近鉄ケーブルネットワーク株式会社_古川様_R・確度進捗_叶浩司.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250610_近鉄ケーブルネットワーク株式会社_古川様_R・確度進捗_叶浩司_extracted.json
#
# [516/555] 20250630_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm
# Processing: 20250630_高輝度光科学研究センター_松原様_確度進捗_鎌田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250630_高輝度光科学研究センター_松原様_確度進捗_鎌田_extracted.json
#
# [517/555] 20250605_東京科学大学_小倉 俊一郎 先生_V_津江.xlsm
# Processing: 20250605_東京科学大学_小倉 俊一郎 先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250605_東京科学大学_小倉 俊一郎 先生_V_津江_extracted.json
#
# [518/555] 20250715_名古屋大学_周月霞先生_V_河合.xlsm
# Processing: 20250715_名古屋大学_周月霞先生_V_河合.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250715_名古屋大学_周月霞先生_V_河合_extracted.json
#
# [519/555] 20250704_NTTイノベーティブデバイス_鈴木様_V_上瀬（20250623）.xlsm
# Processing: 20250704_NTTイノベーティブデバイス_鈴木様_V_上瀬（20250623）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250704_NTTイノベーティブデバイス_鈴木様_V_上瀬（20250623）_extracted.json
#
# [520/555] 20250604_三菱重工業_滝沢_V_安野.xlsm
# Processing: 20250604_三菱重工業_滝沢_V_安野.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250604_三菱重工業_滝沢_V_安野_extracted.json
#
# [521/555] 20250617_九州大学_呂国偉_V_安野.xlsm
# Processing: 20250617_九州大学_呂国偉_V_安野.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250617_九州大学_呂国偉_V_安野_extracted.json
#
# [522/555] 20250627_産業技術総合研究所_小林様_V_宮田.xlsm
# Processing: 20250627_産業技術総合研究所_小林様_V_宮田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250627_産業技術総合研究所_小林様_V_宮田_extracted.json
#
# [523/555] 20250612_東京科学大学_川井 清彦 先生_V_津江.xlsm
# Processing: 20250612_東京科学大学_川井 清彦 先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_東京科学大学_川井 清彦 先生_V_津江_extracted.json
#
# [524/555] 20250610_SOKEN_清水様_V_河合.xlsm
# Processing: 20250610_SOKEN_清水様_V_河合.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250610_SOKEN_清水様_V_河合_extracted.json
#
# [525/555] 20250610_徳島大学_檜垣様_確度進捗_鎌田.xlsm
# Processing: 20250610_徳島大学_檜垣様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250610_徳島大学_檜垣様_確度進捗_鎌田_extracted.json
#
# [526/555] 20250606_徳島大学_檜垣様_確度進捗_鎌田.xlsm
# Processing: 20250606_徳島大学_檜垣様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_徳島大学_檜垣様_確度進捗_鎌田_extracted.json
#
# [527/555] 20250619_CSY_Mark様_確度進捗_鎌田.xlsm
# Processing: 20250619_CSY_Mark様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_CSY_Mark様_確度進捗_鎌田_extracted.json
#
# [528/555] 20250724_Blue Laser Fusion_客先担当銘小原様__鎌田（20250724）.xlsm
# Processing: 20250724_Blue Laser Fusion_客先担当銘小原様__鎌田（20250724）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250724_Blue Laser Fusion_客先担当銘小原様__鎌田（20250724）_extracted.json
#
# [529/555] 20250725_産業技術総合研究所_和田雅人_V・確度進捗_宮田.xlsm
# Processing: 20250725_産業技術総合研究所_和田雅人_V・確度進捗_宮田.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250725_産業技術総合研究所_和田雅人_V・確度進捗_宮田_extracted.json
#
# [530/555] 20250626_NIC_武智宏人_R_大久保.xlsm
# Processing: 20250626_NIC_武智宏人_R_大久保.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250626_NIC_武智宏人_R_大久保_extracted.json
#
# [531/555] 20250619_NTTイノベーティブデバイス_中山様_V_セブンシックス上瀬_清水追記.xlsm
# Processing: 20250619_NTTイノベーティブデバイス_中山様_V_セブンシックス上瀬_清水追記.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_NTTイノベーティブデバイス_中山様_V_セブンシックス上瀬_清水追記_extracted.json
#
# [532/555] 20250703_KCN京都_田村 望美_R_叶杉山.xlsm
# Processing: 20250703_KCN京都_田村 望美_R_叶杉山.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250703_KCN京都_田村 望美_R_叶杉山_extracted.json
#
# [533/555] 20250606_AIST_石井紀代_確度進捗_津江.xlsm
# Processing: 20250606_AIST_石井紀代_確度進捗_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_AIST_石井紀代_確度進捗_津江_extracted.json
#
# [534/555] 20250729_三重大学_田港先生_V_河合（20250723）.xlsm
# Processing: 20250729_三重大学_田港先生_V_河合（20250723）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250729_三重大学_田港先生_V_河合（20250723）_extracted.json
#
# [535/555] 20250613_徳島大学_髙山様_確度進捗_鎌田.xlsm
# Processing: 20250613_徳島大学_髙山様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250613_徳島大学_髙山様_確度進捗_鎌田_extracted.json
#
# [536/555] 20250617_東北大学ー松隈啓様_V_山下真弘.xlsm
# Processing: 20250617_東北大学ー松隈啓様_V_山下真弘.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250617_東北大学ー松隈啓様_V_山下真弘_extracted.json
#
# [537/555] 20250612_阪大ILE _有川_V_加賀.xlsm
# Processing: 20250612_阪大ILE _有川_V_加賀.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_阪大ILE _有川_V_加賀_extracted.json
#
# [538/555] 20250619_NTTイノベーティブデバイス_西田様_V_上瀬_清水追記.xlsm
# Processing: 20250619_NTTイノベーティブデバイス_西田様_V_上瀬_清水追記.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_NTTイノベーティブデバイス_西田様_V_上瀬_清水追記_extracted.json
#
# [539/555] 20250616_NIMS_青野 良香_確度進捗_津江.xlsm
# Processing: 20250616_NIMS_青野 良香_確度進捗_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250616_NIMS_青野 良香_確度進捗_津江_extracted.json
#
# [540/555] 20250617_阪大ILE _荻野_V_加賀.xlsm
# Processing: 20250617_阪大ILE _荻野_V_加賀.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250617_阪大ILE _荻野_V_加賀_extracted.json
#
# [541/555] 20250602_京セラ_忠内様_V_河合.xlsm
# Processing: 20250602_京セラ_忠内様_V_河合.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250602_京セラ_忠内様_V_河合_extracted.json
#
# [542/555] 20250612_santec_早水友洋_V_安野.xlsm
# Processing: 20250612_santec_早水友洋_V_安野.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_santec_早水友洋_V_安野_extracted.json
#
# [543/555] 20250625_倉敷ケーブルテレビ_米田泰介_R_叶杉山.xlsm
# Processing: 20250625_倉敷ケーブルテレビ_米田泰介_R_叶杉山.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250625_倉敷ケーブルテレビ_米田泰介_R_叶杉山_extracted.json
#
# [544/555] 20250729_高輝度光科学研究センター_松原様_確度進捗_鎌田（20250729）.xlsm
# Processing: 20250729_高輝度光科学研究センター_松原様_確度進捗_鎌田（20250729）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250729_高輝度光科学研究センター_松原様_確度進捗_鎌田（20250729）_extracted.json
#
# [545/555] 20250605_東京科学大学_西山 伸宏 先生_V_津江.xlsm
# Processing: 20250605_東京科学大学_西山 伸宏 先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250605_東京科学大学_西山 伸宏 先生_V_津江_extracted.json
#
# [546/555] 20250619_NEC_中村康平_V_大久保.xlsm
# Processing: 20250619_NEC_中村康平_V_大久保.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250619_NEC_中村康平_V_大久保_extracted.json
#
# [547/555] 20250704_石川コンピュータセンター_北澤勝之_R_大久保.xlsm
# Processing: 20250704_石川コンピュータセンター_北澤勝之_R_大久保.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250704_石川コンピュータセンター_北澤勝之_R_大久保_extracted.json
#
# [548/555] 20250604_東京科学大学_鍵 直樹先生_V_津江.xlsm
# Processing: 20250604_東京科学大学_鍵 直樹先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250604_東京科学大学_鍵 直樹先生_V_津江_extracted.json
#
# [549/555] 20250606_宇都宮大学_山本様_確度進捗_鎌田.xlsm
# Processing: 20250606_宇都宮大学_山本様_確度進捗_鎌田.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250606_宇都宮大学_山本様_確度進捗_鎌田_extracted.json
#
# [550/555] 20250610_電気通信大学_藤井 威生 先生_V_津江.xlsm
# Processing: 20250610_電気通信大学_藤井 威生 先生_V_津江.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250610_電気通信大学_藤井 威生 先生_V_津江_extracted.json
#
# [551/555] 20250715_ブロードバンドタワー_小島良光_R_大久保.xlsm
# Processing: 20250715_ブロードバンドタワー_小島良光_R_大久保.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250715_ブロードバンドタワー_小島良光_R_大久保_extracted.json
#
# [552/555] 20250729_三重大学_大田垣先生_V_河合（20250723）.xlsm
# Processing: 20250729_三重大学_大田垣先生_V_河合（20250723）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250729_三重大学_大田垣先生_V_河合（20250723）_extracted.json
#
# [553/555] 20250604_理化学研究所ー_大町 紘平_R_山下真弘.xlsm
# Processing: 20250604_理化学研究所ー_大町 紘平_R_山下真弘.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250604_理化学研究所ー_大町 紘平_R_山下真弘_extracted.json
#
# [554/555] 20250723_菱光社_木村様_R_河合（20250723）.xlsm
# Processing: 20250723_菱光社_木村様_R_河合（20250723）.xlsm (報告書, 97x21)
# 97
# 💾 Saved: outputs/20250723_菱光社_木村様_R_河合（20250723）_extracted.json
#
# [555/555] 20250612_TDK株式会社_上野様_V_久保寺.xlsm
# Processing: 20250612_TDK株式会社_上野様_V_久保寺.xlsm (営業 (フォーマット案_営業本部）, 71x21)
# 71
# 💾 Saved: outputs/20250612_TDK株式会社_上野様_V_久保寺_extracted.json
# 💾 Saved: outputs/all_extractions.json

# %%
import pandas as pd
file_path = "Sevensix_dropbox/機密レベル3/企画管理本部/業務推進部/売上台帳/18期_売上_納期管理台帳.xlsx"
df = pd.read_excel(file_path, sheet_name="18期売上台帳", header=None)
key_column="受注番号"
# Step 2: Detect header rows by searching for key column name
header_indices = df.index[df.apply(lambda row: row.astype(str).str.contains(key_column).any(), axis=1)].tolist()
header_indices
# Out:
# [9, 318, 784, 1198, 1714, 1968, 2280, 2588, 2885, 3190, 3443, 3793, 4096]

# %%
import pandas as pd

def read_multi_table_excel(file_path, sheet_name="18期売上台帳", key_column="受注番号"):
    # Step 1: Read everything without headers
    df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)
    print(df.shape)
    df = df.dropna(how="all").dropna(axis=1, how='all') 
    print(df.shape)
    # Step 2: Detect header rows by searching for key column name
    header_indices = df.index[df.apply(lambda row: row.astype(str).str.contains(key_column).any(), axis=1)].tolist()
    
    all_chunks = []

    for i, start_idx in enumerate(header_indices):
        end_idx = header_indices[i+1] if i+1 < len(header_indices) else len(df)

        # extract block
        block = df.iloc[start_idx:end_idx].reset_index(drop=True)

        # first row is the header
        header = block.iloc[0].fillna("").astype(str).tolist()

        # Make headers unique (important: since "in charge" and others repeat)
        seen = {}
        unique_headers = []
        for col in header:
            if col in seen:
                seen[col] += 1
                unique_headers.append(f"{col}_{seen[col]}")
            else:
                seen[col] = 0
                unique_headers.append(col)

        block.columns = unique_headers
        block = block.drop(0).reset_index(drop=True)

        # skip empty chunks
        if not block.empty:
            block["__TableBlock__"] = i - 1  # keep track of which block (month/section)
            all_chunks.append(block)

    # Step 3: Combine everything
    if not all_chunks:
        raise ValueError("No tables were found. Check key_column name.")

    final_df = pd.concat(all_chunks, ignore_index=True)
    return final_df


# Usage
file_path = "Sevensix_dropbox/機密レベル3/企画管理本部/業務推進部/売上台帳/18期_売上_納期管理台帳.xlsx"
clean_df = read_multi_table_excel(file_path,sheet_name="18期売上台帳", key_column="受注番号")

print(clean_df.head())
print(clean_df.shape)
# Out:
# Raw shape: (351105, 53)
# Trimmed shape: (4334, 53)
# Common columns: {'', '_3', '_4', '_2', '_1'}
#         _3   _4   _2    _1  __TableBlock__
# 0  04  NaN  NaN  NaN  17.0               1
# 1  04  NaN  NaN    〇  17.0               1
# 2  04  NaN  NaN    〇  17.0               1
# 3  04  NaN  NaN    〇  17.0               1
# 4  04  NaN  NaN    〇  17.0               1
# Final shape: (4312, 6)

# %%
import pandas as pd

def read_multi_table_excel(file_path, sheet_name="18期売上台帳", key_column="受注番号"):
    # Step 1: Read raw sheet without headers
    df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)
    df = df.dropna(how="all").dropna(axis=1, how="all")
    print(df.shape)
    # Step 2: Detect header rows by searching for key_column
    header_indices = df.index[
        df.apply(lambda row: row.astype(str).str.contains(key_column).any(), axis=1)
    ].tolist()

    tables = {}

    for i, start_idx in enumerate(header_indices):
        end_idx = header_indices[i+1] if i+1 < len(header_indices) else len(df)

        # extract one block
        block = df.iloc[start_idx:end_idx].reset_index(drop=True)

        # --- Common heading (from first row) ---
        header = block.iloc[0].fillna("").astype(str).tolist()

        # Ensure unique column names
        seen = {}
        unique_headers = []
        for col in header:
            if col in seen:
                seen[col] += 1
                unique_headers.append(f"{col}_{seen[col]}")
            else:
                seen[col] = 0
                unique_headers.append(col)

        # Set headers
        block.columns = unique_headers
        block = block.drop(0).reset_index(drop=True)
        print(block.shape)
       
       
            
        if not block.empty:
            table_heading = f"Table_{i+1}"  # you can also take heading text from another row if needed
            block["__TableBlock__"] = i - 1

    if not tables:
        raise ValueError("No tables were found. Check key_column name.")

    return tables


# Usage
file_path = "Sevensix_dropbox/機密レベル3/企画管理本部/業務推進部/売上台帳/18期_売上_納期管理台帳.xlsx"
tables_dict = read_multi_table_excel(file_path, sheet_name="18期売上台帳", key_column="担当")

# Print each table separately
for heading, table in tables_dict.items():
    print(f"\n=== {heading} ===")
    print(table.head())
    print(table.shape)
# Out:
# Original shape: (4334, 53)
# Table_1 shape: (298, 54)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 61
#      59 # Usage
#      60 file_path = "Sevensix_dropbox/機密レベル3/企画管理本部/業務推進部/売上台帳/18期_売上_納期管理台帳.xlsx"
# ---> 61 tables_dict = read_multi_table_excel(file_path, sheet_name="18期売上台帳", key_column="受注番号")
#      63 # Print each table separately
#      64 for heading, table in tables_dict.items():
#
# Cell In[28], line 20, in read_multi_table_excel(file_path, sheet_name, key_column)
#      18 end_idx = start_idx + 1
#      19 while end_idx < len(df):
# ---> 20     key_cell = df.iloc[end_idx, df.iloc[start_idx].astype(str).tolist().index(key_column)]
#      21     if pd.isna(key_cell) or str(key_cell).strip() == "":
#      22         break
#
# ValueError: '受注番号' is not in list

# %%
import pandas as pd

def read_multi_table_excel(file_path, sheet_name="18期売上台帳", key_column="受注番号"):
    # Step 1: Read raw sheet without headers
    df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)
    df = df.dropna(how="all").dropna(axis=1, how="all")
    print("Original shape:", df.shape)

    # Step 2: Detect header rows by searching for key_column
    header_indices = df.index[
        df.apply(lambda row: row.astype(str).str.contains(key_column).any(), axis=1)
    ].tolist()
    print(header_indices)
    tables = {}

    for i, start_idx in enumerate(header_indices):
        header_row = df.iloc[start_idx].astype(str).tolist()
        print("header_row: ",header_row)
        # --- Find key_column index safely ---
        key_col_idx = None
        for idx, val in enumerate(header_row):
            if key_column in val:
                key_col_idx = idx
                break
        if key_col_idx is None:
            raise ValueError(f"Key column '{key_column}' not found in header row {start_idx}")

        # --- Determine end of table by checking if key_column cell is empty ---
        end_idx = start_idx + 1
        while end_idx < len(df):
            key_cell = df.iloc[end_idx, key_col_idx]
            if pd.isna(key_cell) or str(key_cell).strip() == "":
                break
            end_idx += 1

        # extract one block
        block = df.iloc[start_idx:end_idx].reset_index(drop=True)

        # --- Common heading (from first row) ---
        header = block.iloc[0].fillna("").astype(str).tolist()

        # Ensure unique column names
        seen = {}
        unique_headers = []
        for col in header:
            if col in seen:
                seen[col] += 1
                unique_headers.append(f"{col}_{seen[col]}")
            else:
                seen[col] = 0
                unique_headers.append(col)

        # Set headers
        block.columns = unique_headers
        block = block.drop(0).reset_index(drop=True)

        # Only keep block if it has data
        if not block.empty:
            table_heading = f"Table_{i+1}"  # Or take heading from row above
            block["__TableBlock__"] = i
            tables[table_heading] = block
            print(f"{table_heading} shape:", block.shape)

    if not tables:
        raise ValueError("No tables were found. Check key_column name.")

    return tables


# Usage
file_path = "Sevensix_dropbox/機密レベル3/企画管理本部/業務推進部/売上台帳/18期_売上_納期管理台帳.xlsx"
tables_dict = read_multi_table_excel(file_path, sheet_name="18期売上台帳", key_column="担当")

# Print each table separately
for heading, table in tables_dict.items():
    print(f"\n=== {heading} ===")
    print(table.head())
    print(table.shape)
# Out:
# Original shape: (4334, 53)
# [9, 318, 784, 1198, 1714, 1968, 2280, 2588, 2885, 3190, 3443, 3793, 4096]
# header_row:  ['完了', 'nan', 'nan', '担当', '受注番号', '受注日', '得意先名', '担当', '#', '型番', '商品名', '数量', '単位', '通貨単位', '販売単価', '送料/手数料', '小計', '円価小計', '円貨合計', '仕入先名', '通貨単位', '仕入単価', '送料/手数料', '外貨小計', '円価小計', '円価合計', '粗利益', '利益率', '備考', '売上日', '新規/既存', '区別', '営業所', 'アプリケーション', '受注経路', '量産', '入札', '他部署', '名称', '自社製品', '～2024/11納品', '2024/12～納品', 'nan', 'nan', 'ﾊﾞｲﾔｰ希望納期', 'メーカ回答 (一次)', 'メーカ回答 (二次)', '備考(納期)', '希望納期から遅延の理由', '売上予定月', '備考(作業用)', 'nan', '営業サイド自由記載']
# Table_1 shape: (298, 54)
# header_row:  ['済', 'nan', '12.0', 'N', 'O2312004N', '2023-12-04 00:00:00', '株式会社Preferred Networks', '金井', '1', 'TR-FC85S-N00', '100GBASE-SR4 QSFP28 Optical Transceiver', '6', 'PCS', 'JPY', '11000', '0', '66000', '66000', '66000', '在庫 S2310-2 InnoLight', 'USD', '39', '0', '234', '36504', '36504', '29496', '0.446909090909091', 'nan', '45268', '既存', '民間', '東京', 'DC', '営業案内', '-', '-', '-', 'Preferred Networks', 'nan', '〇', 'nan', '〇', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', '12', 'nan', 'nan', 'nan']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 72
#      70 # Usage
#      71 file_path = "Sevensix_dropbox/機密レベル3/企画管理本部/業務推進部/売上台帳/18期_売上_納期管理台帳.xlsx"
# ---> 72 tables_dict = read_multi_table_excel(file_path, sheet_name="18期売上台帳", key_column="担当")
#      74 # Print each table separately
#      75 for heading, table in tables_dict.items():
#
# Cell In[34], line 26, in read_multi_table_excel(file_path, sheet_name, key_column)
#      24         break
#      25 if key_col_idx is None:
# ---> 26     raise ValueError(f"Key column '{key_column}' not found in header row {start_idx}")
#      28 # --- Determine end of table by checking if key_column cell is empty ---
#      29 end_idx = start_idx + 1
#
# ValueError: Key column '担当' not found in header row 318

# %%
import pandas as pd

def read_multi_table_excel(file_path, sheet_name="18期売上台帳", key_column="受注番号"):
    # Step 1: Read raw sheet without headers
    df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)

    # Drop empty rows/columns first to speed up
    df = df.dropna(how="all").dropna(axis=1, how="all")
    print("Cleaned shape:", df.shape)

    tables = {}
    i = 0
    row_idx = 0

    while row_idx < len(df):
        row = df.iloc[row_idx]
        # Detect header row by checking if key_column exists in this row
        if row.astype(str).str.contains(key_column).any():
            header_row = row.astype(str).tolist()

            # Find key column index safely
            key_col_idx = None
            for idx, val in enumerate(header_row):
                if key_column in val:
                    key_col_idx = idx
                    break
            if key_col_idx is None:
                row_idx += 1
                continue  # should not happen

            # Determine end of table by checking key column empty
            end_idx = row_idx + 1
            while end_idx < len(df):
                key_cell = df.iloc[end_idx, key_col_idx]
                if pd.isna(key_cell) or str(key_cell).strip() == "":
                    break
                end_idx += 1

            # Extract block
            block = df.iloc[row_idx:end_idx].reset_index(drop=True)

            # --- Set headers ---
            header = block.iloc[0].fillna("").astype(str).tolist()
            seen = {}
            unique_headers = []
            for col in header:
                if col in seen:
                    seen[col] += 1
                    unique_headers.append(f"{col}_{seen[col]}")
                else:
                    seen[col] = 0
                    unique_headers.append(col)

            block.columns = unique_headers
            block = block.drop(0).reset_index(drop=True)

            # Only keep block if it has data
            if not block.empty:
                table_heading = f"Table_{i+1}"
                block["__TableBlock__"] = i
                tables[table_heading] = block
                print(f"{table_heading} shape:", block.shape)
                i += 1

            row_idx = end_idx
        else:
            row_idx += 1

    if not tables:
        raise ValueError("No tables were found. Check key_column name.")
    
   
    full_table = pd.concat(tables.values(), ignore_index=True)
    if "" in full_table.columns:
        full_table.drop(columns=[""],inplace=True)


    return full_table


# Usage
file_path = "Sevensix_dropbox/機密レベル3/企画管理本部/業務推進部/売上台帳/18期_売上_納期管理台帳.xlsx"
tables_dict = read_multi_table_excel(file_path, sheet_name="18期売上台帳", key_column="担当")
# --- Concatenate all tables into one ---


# print("Concatenated table shape:", all_tables_df.shape)
# print(all_tables_df.head())
# # Print each table separately
# for heading, table in tables_dict.items():
#     print(f"\n=== {heading} ===")
#     print(table.head())
#     print(table.columns)
    # print(table.shape)
    # table.to_csv(f"{heading}.csv",index=False)
# Out:
# Cleaned shape: (4334, 53)
# Table_1 shape: (298, 54)
# Table_2 shape: (455, 54)
# Table_3 shape: (403, 54)
# Table_4 shape: (505, 54)
# Table_5 shape: (243, 54)
# Table_6 shape: (301, 54)
# Table_7 shape: (297, 54)
# Table_8 shape: (286, 54)
# Table_9 shape: (295, 54)
# Table_10 shape: (242, 54)
# Table_11 shape: (339, 54)
# Table_12 shape: (292, 54)
# Table_13 shape: (292, 54)

# %%
tables_dict.columns
# Out:
# Index(['完了', '_1', '担当', '受注番号', '受注日', '得意先名', '担当_1', '#', '型番', '商品名', '数量',
#        '単位', '通貨単位', '販売単価', '送料/手数料', '小計', '円価小計', '円貨合計', '仕入先名', '通貨単位_1',
#        '仕入単価', '送料/手数料_1', '外貨小計', '円価小計_1', '円価合計', '粗利益', '利益率', '備考', '売上日',
#        '新規/既存', '区別', '営業所', 'アプリケーション', '受注経路', '量産', '入札', '他部署', '名称',
#        '自社製品', '～2024/11納品', '2024/12～納品', '_2', '_3', 'ﾊﾞｲﾔｰ希望納期',
#        'メーカ回答 (一次)', 'メーカ回答 (二次)', '備考(納期)', '希望納期から遅延の理由', '売上予定月', '備考(作業用)',
#        '_4', '営業サイド自由記載', '__TableBlock__', '～2024/03納品', '2024/04以降納品', '_5',
#        '_6', '_7', '客先注文書番号', '_8'],
#       dtype='object')

# %%
# --- Concatenate all tables into one ---
all_tables_df = pd.concat(tables_dict.values(), ignore_index=True)

print("Concatenated table shape:", all_tables_df.shape)
print(all_tables_df.head())
# Out:
# Concatenated table shape: (4248, 61)
#   完了        _1 担当        受注番号                  受注日              得意先名 担当_1  #  \
# 0  済  04  17.0  M  O2304026M.  2023-04-03 00:00:00           株式会社ニコン   岩田  1
# 1  済  04  17.0  D   O2304043D  2023-04-03 00:00:00          株式会社ディスコ   村上  1
# 2  済  04  17.0  F   O2304049F  2023-04-03 00:00:00  株式会社トーメーコーポレーション   西尾  1
# 3  済  04  17.0  F   O2304049F  2023-04-03 00:00:00  株式会社トーメーコーポレーション   西尾  1
# 4  済  04  17.0  D   O2304055D  2023-04-03 00:00:00          株式会社ディスコ   村上  1
#
#                                                   型番  ...   _4 営業サイド自由記載  \
# 0  OEOFF-1986.5-0.05-3-0.05-99.9-2-PM-GDF-10/130-...  ...  NaN       NaN
# 1                 EYP-DFB-1064-00040-1500-BFY02-0006  ...  NaN       NaN
# 2                                 FCM-06-9-J0-2-L-RS  ...  NaN       NaN
# 3                                 FCM-06-9-J0-2-L-RS  ...  NaN       NaN
# 4                 EYP-DFB-1064-00040-1500-BFY02-0006  ...  NaN       NaN
#
#   __TableBlock__ ～2024/03納品 2024/04以降納品   _5   _6   _7 客先注文書番号   _8
# 0              0        NaN         NaN  NaN  NaN  NaN     NaN  NaN
# 1              0        NaN         NaN  NaN  NaN  NaN     NaN  NaN
# 2              0        NaN         NaN  NaN  NaN  NaN     NaN  NaN
# 3              0        NaN         NaN  NaN  NaN  NaN     NaN  NaN
# 4              0        NaN         NaN  NaN  NaN  NaN     NaN  NaN
#
# [5 rows x 61 columns]

# %%
all_tables_df.shape
# Out:
# (4248, 61)

# %%
import pandas as pd
import glob
import os

def combine_excel_files(folder_path: str, sheet_name: str = 0, skip_files: list = []) -> pd.DataFrame:
    # Find all Excel files in the folder
    files = glob.glob(f"{folder_path}/*.xlsx")
    
    df_list = []
    for file in files:
        file_name = os.path.basename(file)  # only file name
        if file_name in skip_files:         # compare names only
            print(f"Skipping {file_name}")
            continue
        try:
            df = pd.read_excel(file, sheet_name=sheet_name)
            df = df.dropna(how="all").dropna(axis=1, how="all")
            
            df_list.append(df)
            print("file: ",df.shape)
            print(f"{file_name} processed")
        except Exception as e:
            print(f"Error reading {file_name}: {e}")
    
    if not df_list:
        print("⚠️ No valid DataFrames to concatenate.")
        return pd.DataFrame()  # return empty DataFrame
    
    # Combine into one DataFrame
    full_table = pd.concat(df_list, ignore_index=True)
    print("columns: ",full_table.columns)
    if " " in full_table.columns or '　' in full_table.columns or "" in full_table.columns:
        full_table.drop(columns=['　'],inplace=True)
    return full_table
# Example usage:
df = combine_excel_files(
    "Sevensix_dropbox/機密レベル3/企画管理本部/業務推進部/売上台帳", 
    
    # sheet_name="SalesData",
    skip_files=["18期_売上_納期管理台帳.xlsx"]
)
print(df.shape)
df.columns
# Out:
# file:  (3989, 76)
# 【使用不可】★14-15期_納期.xlsx processed
# file:  (3562, 29)
# 【使用不可】16期-17期_納期 (1).xlsx processed
# file:  (1928, 36)
# 【使用不可】17期_納期(20230401~20231130) (1).xlsx processed
# Skipping 18期_売上_納期管理台帳.xlsx
# columns:  Index(['　', '契約No', 'P.O.№', '客先名', 'アイテム＃', '商品コード', '商品名', '数量', '出荷数',
#        '注文書番号',
#        ...
#        'メーカ回答\n9/14', 'メーカ回答\n9/22', 'メーカ回答\n9/29', 'メーカ回答\n10/13',
#        'メーカ回答\n10/20', 'メーカ回答\n10/27', 'メーカ回答\n11/2', 'メーカ回答\n11/2.1',
#        'メーカ回答\n11/10', 'メーカ回答\n11/24'],
#       dtype='object', length=101)
# (9479, 100)
# Index(['契約No', 'P.O.№', '客先名', 'アイテム＃', '商品コード', '商品名', '数量', '出荷数', '注文書番号',
#        '仕入先コード', '仕入先名', 'ﾒｰｶｰｺｰﾄﾞ', 'ﾒｰｶｰ名', 'Mへの発注金額', '受注日', 'ﾊﾞｲﾔｰ希望納期',
#        'メーカ回答\n初回', 'メーカ回答\n2/22', 'メーカ回答\n3/19', 'メーカ回答\n3/25', 'メーカ回答\n4/1',
#        'メーカ回答\n4/8', 'メーカ回答\n4/15', 'メーカ回答\n4/21', 'メーカ回答\n4/28', 'メーカ回答\n5/7',
#        'メーカ回答\n5/13', 'メーカ回答\n5/20', 'メーカ回答\n5/27', 'メーカ回答\n6/3',
#        'メーカ回答\n6/10', 'メーカ回答\n6/17', 'メーカ回答\n6/24', 'メーカ回答\n7/1', 'メーカ回答\n7/9',
#        'メーカ回答\n7/16', 'メーカ回答\n7/26', 'メーカ回答\n7/30', 'メーカ回答\n8/6',
#        'メーカ回答\n8/13', 'メーカ回答\n8/19', 'メーカ回答\n8/26', 'メーカ回答\n9/1', 'メーカ回答\n9/8',
#        'メーカ回答\n9/17', 'メーカ回答\n9/24（BWTは9/22）', 'メーカ回答\n9/30（Optizoneは9/27）',
#        'メーカ回答\n10/7', 'メーカ回答\n10/15', 'メーカ回答\n10/21', 'メーカ回答\n10/2８',
#        'メーカ回答\n11/4', 'メーカ回答\n11/12　（BWTは11/10回答時）', 'メーカ回答\n11/18',
#        'メーカ回答\n11/25', 'メーカ回答\n12/2', 'メーカ回答\n12/10', 'メーカ回答\n12/16',
#        'メーカ回答\n12/24', 'メーカ回答\n1/6', 'メーカ回答\n1/14', 'メーカ回答\n1/21',
#        'メーカ回答\n1/28(BWTは1/24）', 'メーカ回答\n2/4', 'メーカ回答\n2/9', 'メーカ回答\n2/17',
#        'メーカ回答\n2/24', 'メーカ回答\n3/4', 'メーカ回答\n3/11', 'メーカ回答\n3/18',
#        'メーカ回答\n3/25.1', '出荷日', '客先回答日', '備考', 'Unnamed: 75', '受注金額',
#        'メーカ回答\n2/3', 'メーカ回答\n2/10', 'メーカ回答\n3/3', 'メーカ回答\n3/10', 'メーカ回答\n3/16',
#        'メーカ回答\n3/24', 'メーカ回答\n3/29', '備考（O列：仕入れ額、,S列：受注金額）', 'メーカ回答\n8/4',
#        'メーカ回答\n8/10', 'メーカ回答\n8/17', 'メーカ回答\n8/24', 'メーカ回答\n8/30',
#        'メーカ回答\n9/7', 'メーカ回答\n9/14', 'メーカ回答\n9/22', 'メーカ回答\n9/29',
#        'メーカ回答\n10/13', 'メーカ回答\n10/20', 'メーカ回答\n10/27', 'メーカ回答\n11/2',
#        'メーカ回答\n11/2.1', 'メーカ回答\n11/10', 'メーカ回答\n11/24'],
#       dtype='object')

# %%
df = df.dropna(how='all')   # Drop fully empty rows
df = df.dropna(axis=1, how='all')  # Drop fully empty columns
df.shape
# Out:
# (9479, 101)

# %%
df.head(-10)
# Out:
#         　       契約No                   P.O.№              客先名  アイテム＃  \
# 0       済  O2012147K  契約番号：20-10-21-00158555  国立研究開発法人　理化学研究所    3.0
# 1       済  O2104002N            I210000185-0        ミハル通信株式会社    1.0
# 2       済  O2104003G               AG0Q50N0A         三菱電機株式会社    1.0
# 3       済  O2104004K          2021/01/19付発注書           東京工業大学    2.0
# 4       済  O2104004K          2021/01/19付発注書           東京工業大学    1.0
# ...   ...        ...                     ...              ...    ...
# 9464  NaN  O2311112M        hac-231127-00456           270000    1.0
# 9465  NaN  O2311113E             W2301122004           438400    1.0
# 9466  NaN  O2311113E             W2301122004            84000    2.0
# 9467  NaN  O2311114W        OR-00013773<R05>           220500    1.0
# 9468  NaN  O2311115D                 メール注文にて            17000    1.0
#
#                                                  商品コード  \
# 0                     Yb-doped PCF amplifier including
# 1     MPC-(2+1)x1-B-915/10W-1550-110/454-000-3x50-1.0m
# 2                         PMFC-59-1-50-F-NNN-BBB-P-1.1
# 3                                         A911-100-201
# 4                                                 K112
# ...                                                ...
# 9464                                           MY-1375
# 9465                 WDM-1-520770-2-L-0.25-2 (SR24514)
# 9466                          WDM-1-9851560-2-L-0.25-F
# 9467                                  K976AAHRN-27.00W
# 9468                                            ZAD-6+
#
#                                                     商品名  数量  出荷数  \
# 0     • Forward-pumping monolithic architecture_x000...   1  NaN
# 1                     Multi-mode Pump Combiner((2+1)x1)  30  NaN
# 2     Polarization Maintaining Filter Coupler, 1590+...   6  NaN
# 3        USB-RS485 Adapter kit for new BASIK generation   1  NaN
# 4     Koheras BASIK C15 PM FM 1560.48nm to 2 s.f. re...   1  NaN
# ...                                                 ...  ..  ...
# 9464                     100g Plastic Bottle (IR=1.379)   1    0
# 9465  シングルモードWDMカプラ　1X2型520 & 770nm、FC/APCコネクタ付き、900...   8    0
# 9466  シングルモードWDMカプラ　1X2型　980 & 1560nm、FC/APCコネクタ付き、9...   8    0
# 9467  976nm 27W Wavelength-Stabilized Fiber Coupled ...   1    0
# 9468  Frequency Mixer, Level 7 (LO Power +7 dBm) 0.0...   1    0
#
#                注文書番号  ... メーカ回答\n9/14 メーカ回答\n9/22 メーカ回答\n9/29 メーカ回答\n10/13  \
# 0                NaN  ...         NaN         NaN         NaN          NaN
# 1                NaN  ...         NaN         NaN         NaN          NaN
# 2                NaN  ...         NaN         NaN         NaN          NaN
# 3                NaN  ...         NaN         NaN         NaN          NaN
# 4                NaN  ...         NaN         NaN         NaN          NaN
# ...              ...  ...         ...         ...         ...          ...
# 9464  O2311112M-0026  ...         NaN         NaN         NaN          NaN
# 9465  O2311113E-0049  ...         NaN         NaN         NaN          NaN
# 9466  O2311113E-0049  ...         NaN         NaN         NaN          NaN
# 9467  O2311114W-0009  ...         NaN         NaN         NaN          NaN
# 9468   O2311115D-530  ...         NaN         NaN         NaN          NaN
#
#      メーカ回答\n10/20 メーカ回答\n10/27 メーカ回答\n11/2 メーカ回答\n11/2.1 メーカ回答\n11/10  \
# 0             NaN          NaN         NaN           NaN          NaN
# 1             NaN          NaN         NaN           NaN          NaN
# 2             NaN          NaN         NaN           NaN          NaN
# 3             NaN          NaN         NaN           NaN          NaN
# 4             NaN          NaN         NaN           NaN          NaN
# ...           ...          ...         ...           ...          ...
# 9464          NaN          NaN         NaN           NaN          NaN
# 9465          NaN          NaN         NaN           NaN          NaN
# 9466          NaN          NaN         NaN           NaN          NaN
# 9467          NaN          NaN         NaN           NaN          NaN
# 9468          NaN          NaN         NaN           NaN          NaN
#
#      メーカ回答\n11/24
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 9464          NaN
# 9465          NaN
# 9466          NaN
# 9467          NaN
# 9468          NaN
#
# [9469 rows x 101 columns]

# %%
import pandas as pd

def read_multi_table_excel(file_path, sheet_name=0, key_column="受注番号"):
    # Step 1: Read everything without headers
    df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)

    # Step 2: Detect header rows by searching for key column name
    header_indices = df.index[df.apply(lambda row: row.astype(str).str.contains(key_column).any(), axis=1)].tolist()

    all_chunks = []
    skip_markers = ["受注額合計", "仕入額合計", "粗利益", "利益率"]  # unwanted summary rows

    for i, start_idx in enumerate(header_indices):
        end_idx = header_indices[i+1] if i+1 < len(header_indices) else len(df)

        # extract block
        block = df.iloc[start_idx:end_idx].reset_index(drop=True)

        # first row is the header
        header = block.iloc[0].fillna("").astype(str).tolist()
        print(header)

        # Make headers unique
        seen = {}
        unique_headers = []
        for col in header:
            if col in seen:
                seen[col] += 1
                unique_headers.append(f"{col}_{seen[col]}")
            else:
                seen[col] = 0
                unique_headers.append(col)

        block.columns = unique_headers
        block = block.drop(0).reset_index(drop=True)

        # --- Filter unwanted rows ---
        block = block[
            ~block.astype(str).apply(lambda row: any(marker in "".join(row) for marker in skip_markers), axis=1)
        ]

        # skip empty chunks
        if not block.empty:
            block["__TableBlock__"] = i + 1  # track which block/month
            all_chunks.append(block)

    # Step 3: Combine everything
    if not all_chunks:
        raise ValueError("No tables were found. Check key_column name.")

    final_df = pd.concat(all_chunks, ignore_index=True)

    return final_df


# Usage
file_path = "Sevensix_dropbox/機密レベル3/企画管理本部/業務推進部/売上台帳/18期_売上_納期管理台帳.xlsx"
clean_df = read_multi_table_excel(file_path,sheet_name="18期売上台帳", key_column="受注番号")

print(clean_df.head())
print(clean_df.tail())
# Out:
#   完了        _1 担当        受注番号                  受注日              得意先名 担当_1  #  \
# 0  済  04  17.0  M  O2304026M.  2023-04-03 00:00:00           株式会社ニコン   岩田  1
# 1  済  04  17.0  D   O2304043D  2023-04-03 00:00:00          株式会社ディスコ   村上  1
# 2  済  04  17.0  F   O2304049F  2023-04-03 00:00:00  株式会社トーメーコーポレーション   西尾  1
# 3  済  04  17.0  F   O2304049F  2023-04-03 00:00:00  株式会社トーメーコーポレーション   西尾  1
# 4  済  04  17.0  D   O2304055D  2023-04-03 00:00:00          株式会社ディスコ   村上  1
#
#                                                   型番  ...   _4 営業サイド自由記載  \
# 0  OEOFF-1986.5-0.05-3-0.05-99.9-2-PM-GDF-10/130-...  ...  NaN       NaN
# 1                 EYP-DFB-1064-00040-1500-BFY02-0006  ...  NaN       NaN
# 2                                 FCM-06-9-J0-2-L-RS  ...  NaN       NaN
# 3                                 FCM-06-9-J0-2-L-RS  ...  NaN       NaN
# 4                 EYP-DFB-1064-00040-1500-BFY02-0006  ...  NaN       NaN
#
#   __TableBlock__ ～2024/03納品 2024/04以降納品   _5   _6   _7 客先注文書番号   _8
# 0              1        NaN         NaN  NaN  NaN  NaN     NaN  NaN
# 1              1        NaN         NaN  NaN  NaN  NaN     NaN  NaN
# 2              1        NaN         NaN  NaN  NaN  NaN     NaN  NaN
# 3              1        NaN         NaN  NaN  NaN  NaN     NaN  NaN
# 4              1        NaN         NaN  NaN  NaN  NaN     NaN  NaN
#
# [5 rows x 61 columns]
#          完了        _1   担当 受注番号  受注日 得意先名 担当_1    #   型番  ...   _4 営業サイド自由記載  \
# 351039  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN       NaN
# 351040  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN       NaN
# 351041  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN       NaN
# 351042  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN       NaN
# 351043  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    4  ...  NaN       NaN
#
#        __TableBlock__ ～2024/03納品 2024/04以降納品   _5   _6   _7 客先注文書番号   _8
# 351039             13        NaN         NaN  NaN  NaN  NaN     NaN  NaN
# 351040             13        NaN         NaN  NaN  NaN  NaN     NaN  NaN
# 351041             13        NaN         NaN  NaN  NaN  NaN     NaN  NaN
# 351042             13        NaN         NaN  NaN  NaN  NaN     NaN  NaN
# 351043             13        NaN         NaN  NaN  NaN  NaN     NaN  NaN
#
# [5 rows x 61 columns]

# %%
file_path = "Sevensix_dropbox/機密レベル3/企画管理本部/業務推進部/売上台帳/18期_売上_納期管理台帳.xlsx"
sheet_name="18期売上台帳"
key_column="受注番号"
# Step 1: Read everything without headers
df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)

# Step 2: Detect header rows by searching for key column name
header_indices = df.index[df.apply(lambda row: row.astype(str).str.contains(key_column).any(), axis=1)].tolist()
header_indices
# Out:
# [9, 318, 784, 1198, 1714, 1968, 2280, 2588, 2885, 3190, 3443, 3793, 4096]

# %%
all_chunks = []
skip_markers = ["受注額合計", "仕入額合計", "粗利益", "利益率"]  # unwanted summary rows

for i, start_idx in enumerate(header_indices):
    end_idx = header_indices[i+1] if i+1 < len(header_indices) else len(df)

    # extract block
    block = df.iloc[start_idx:end_idx].reset_index(drop=True)
    
    # first row is the header
    header = block.iloc[0].fillna("").astype(str).tolist()
    print(header)
# Out:
# ['完了', '', '', '担当', '受注番号', '受注日', '得意先名', '担当', '#', '型番', '商品名', '数量', '単位', '通貨単位', '販売単価', '送料/手数料', '小計', '円価小計', '円貨合計', '仕入先名', '通貨単位', '仕入単価', '送料/手数料', '外貨小計', '円価小計', '円価合計', '粗利益', '利益率', '備考', '売上日', '新規/既存', '区別', '営業所', 'アプリケーション', '受注経路', '量産', '入札', '他部署', '名称', '自社製品', '～2024/11納品', '2024/12～納品', '', '', 'ﾊﾞｲﾔｰ希望納期', 'メーカ回答 (一次)', 'メーカ回答 (二次)', '備考(納期)', '希望納期から遅延の理由', '売上予定月', '備考(作業用)', '', '営業サイド自由記載']
# ['完了', '', '', '担当', '受注番号', '受注日', '得意先名', '担当', '#', '型番', '商品名', '数量', '単位', '通貨単位', '販売単価', '送料/手数料', '小計', '円価小計', '円貨合計', '仕入先名', '通貨単位', '仕入単価', '送料/手数料', '外貨小計', '円価小計', '円価合計', '粗利益', '利益率', '備考', '売上日', '新規/既存', '区別', '営業所', 'アプリケーション', '受注経路', '量産', '入札', '他部署', '名称', '自社製品', '～2024/03納品', '2024/04以降納品', '', '', 'ﾊﾞｲﾔｰ希望納期', 'メーカ回答 (一次)', 'メーカ回答 (二次)', '備考(納期)', '希望納期から遅延の理由', '売上予定月', '備考(作業用)', '', '']
# ['完了', '', '', '担当', '受注番号', '受注日', '得意先名', '担当', '#', '型番', '商品名', '数量', '単位', '通貨単位', '販売単価', '送料/手数料', '小計', '円価小計', '円貨合計', '仕入先名', '通貨単位', '仕入単価', '送料/手数料', '外貨小計', '円価小計', '円価合計', '粗利益', '利益率', '備考', '売上日', '新規/既存', '区別', '営業所', 'アプリケーション', '受注経路', '量産', '入札', '他部署', '名称', '自社製品', '～2024/03納品', '2024/04以降納品', '', '', 'ﾊﾞｲﾔｰ希望納期', 'メーカ回答 (一次)', 'メーカ回答 (二次)', '備考(納期)', '希望納期から遅延の理由', '売上予定月', '備考(作業用)', '', '']
# ['完了', '', '', '担当', '受注番号', '受注日', '得意先名', '担当', '#', '型番', '商品名', '数量', '単位', '通貨単位', '販売単価', '送料/手数料', '小計', '円価小計', '円貨合計', '仕入先名', '通貨単位', '仕入単価', '送料/手数料', '外貨小計', '円価小計', '円価合計', '粗利益', '利益率', '備考', '売上日', '新規/既存', '区別', '営業所', 'アプリケーション', '受注経路', '量産', '入札', '他部署', '名称', '自社製品', '～2024/03納品', '2024/04以降納品', '', '', 'ﾊﾞｲﾔｰ希望納期', 'メーカ回答 (一次)', 'メーカ回答 (二次)', '備考(納期)', '希望納期から遅延の理由', '売上予定月', '備考(作業用)', '', '']
# ['完了', '', '', '担当', '受注番号', '受注日', '得意先名', '担当', '#', '型番', '商品名', '数量', '単位', '通貨単位', '販売単価', '送料/手数料', '小計', '円価小計', '円貨合計', '仕入先名', '通貨単位', '仕入単価', '送料/手数料', '外貨小計', '円価小計', '円価合計', '粗利益', '利益率', '備考', '売上日', '新規/既存', '区別', '営業所', 'アプリケーション', '受注経路', '量産', '入札', '他部署', '名称', '自社製品', '～2024/03納品', '', '', '', 'ﾊﾞｲﾔｰ希望納期', 'メーカ回答 (一次)', 'メーカ回答 (二次)', '備考(納期)', '希望納期から遅延の理由', '売上予定月', '備考(作業用)', '', '']
# ['完了', '', '', '担当', '受注番号', '受注日', '得意先名', '担当', '#', '型番', '商品名', '数量', '単位', '通貨単位', '販売単価', '送料/手数料', '小計', '円価小計', '円貨合計', '仕入先名', '通貨単位', '仕入単価', '送料/手数料', '外貨小計', '円価小計', '円価合計', '粗利益', '利益率', '備考', '売上日', '新規/既存', '区別', '営業所', 'アプリケーション', '受注経路', '量産', '入札', '他部署', '名称', '自社製品', '', '', '', '', 'ﾊﾞｲﾔｰ希望納期', 'メーカ回答 (一次)', 'メーカ回答 (二次)', '備考(納期)', '希望納期から遅延の理由', '売上予定月', '備考(作業用)', '', '']
# ['完了', '', '', '担当', '受注番号', '受注日', '得意先名', '担当', '#', '型番', '商品名', '数量', '単位', '通貨単位', '販売単価', '送料/手数料', '小計', '円価小計', '円貨合計', '仕入先名', '通貨単位', '仕入単価', '送料/手数料', '外貨小計', '円価小計', '円価合計', '粗利益', '利益率', '備考', '売上日', '新規/既存', '区別', '営業所', 'アプリケーション', '受注経路', '量産', '入札', '他部署', '名称', '自社製品', '', '', '', '', 'ﾊﾞｲﾔｰ希望納期', 'メーカ回答 (一次)', 'メーカ回答 (二次)', '備考(納期)', '希望納期から遅延の理由', '売上予定月', '備考(作業用)', '', '']
# ['完了', '', '', '担当', '受注番号', '受注日', '得意先名', '担当', '#', '型番', '商品名', '数量', '単位', '通貨単位', '販売単価', '送料/手数料', '小計', '円価小計', '円貨合計', '仕入先名', '通貨単位', '仕入単価', '送料/手数料', '外貨小計', '円価小計', '円価合計', '粗利益', '利益率', '備考', '売上日', '新規/既存', '区別', '営業所', 'アプリケーション', '受注経路', '量産', '入札', '他部署', '名称', '自社製品', '', '', '', '', 'ﾊﾞｲﾔｰ希望納期', 'メーカ回答 (一次)', 'メーカ回答 (二次)', '備考(納期)', '希望納期から遅延の理由', '売上予定月', '備考(作業用)', '', '']
# ['完了', '', '', '担当', '受注番号', '受注日', '得意先名', '担当', '#', '型番', '商品名', '数量', '単位', '通貨単位', '販売単価', '送料/手数料', '小計', '円価小計', '円貨合計', '仕入先名', '通貨単位', '仕入単価', '送料/手数料', '外貨小計', '円価小計', '円価合計', '粗利益', '利益率', '備考', '売上日', '新規/既存', '区別', '営業所', 'アプリケーション', '受注経路', '量産', '入札', '他部署', '名称', '自社製品', '', '', '', '', 'ﾊﾞｲﾔｰ希望納期', 'メーカ回答 (一次)', 'メーカ回答 (二次)', '備考(納期)', '希望納期から遅延の理由', '売上予定月', '備考(作業用)', '客先注文書番号', '']
# ['完了', '', '', '担当', '受注番号', '受注日', '得意先名', '担当', '#', '型番', '商品名', '数量', '単位', '通貨単位', '販売単価', '送料/手数料', '小計', '円価小計', '円貨合計', '仕入先名', '通貨単位', '仕入単価', '送料/手数料', '外貨小計', '円価小計', '円価合計', '粗利益', '利益率', '備考', '売上日', '新規/既存', '区別', '営業所', 'アプリケーション', '受注経路', '量産', '入札', '他部署', '名称', '自社製品', '', '', '', '', 'ﾊﾞｲﾔｰ希望納期', 'メーカ回答 (一次)', 'メーカ回答 (二次)', '備考(納期)', '希望納期から遅延の理由', '売上予定月', '備考(作業用)', '', '']
# ['完了', '', '', '担当', '受注番号', '受注日', '得意先名', '担当', '#', '型番', '商品名', '数量', '単位', '通貨単位', '販売単価', '送料/手数料', '小計', '円価小計', '円貨合計', '仕入先名', '通貨単位', '仕入単価', '送料/手数料', '外貨小計', '円価小計', '円価合計', '粗利益', '利益率', '備考', '売上日', '新規/既存', '区別', '営業所', 'アプリケーション', '受注経路', '量産', '入札', '他部署', '名称', '自社製品', '', '', '', '', 'ﾊﾞｲﾔｰ希望納期', 'メーカ回答 (一次)', 'メーカ回答 (二次)', '備考(納期)', '希望納期から遅延の理由', '売上予定月', '備考(作業用)', '', '']
# ['完了', '', '', '担当', '受注番号', '受注日', '得意先名', '担当', '#', '型番', '商品名', '数量', '単位', '通貨単位', '販売単価', '送料/手数料', '小計', '円価小計', '円貨合計', '仕入先名', '通貨単位', '仕入単価', '送料/手数料', '外貨小計', '円価小計', '円価合計', '粗利益', '利益率', '備考', '売上日', '新規/既存', '区別', '営業所', 'アプリケーション', '受注経路', '量産', '入札', '他部署', '名称', '自社製品', '', '', '', '', 'ﾊﾞｲﾔｰ希望納期', 'メーカ回答 (一次)', 'メーカ回答 (二次)', '備考(納期)', '希望納期から遅延の理由', '売上予定月', '備考(作業用)', '', '']
# ['', '', '', '担当', '受注番号', '受注日', '得意先名', '担当', '#', '型番', '商品名', '数量', '単位', '通貨単位', '販売単価', '送料/手数料', '小計', '円価小計', '円貨合計', '仕入先名', '通貨単位', '仕入単価', '送料/手数料', '外貨小計', '円価小計', '円価合計', '粗利益', '利益率', '備考', '売上日', '新規/既存', '区別', '営業所', 'アプリケーション', '受注経路', '量産', '入札', '他部署', '名称', '自社製品', '', '', '', '', 'ﾊﾞｲﾔｰ希望納期', 'メーカ回答 (一次)', 'メーカ回答 (二次)', '備考(納期)', '希望納期から遅延の理由', '売上予定月', '備考(作業用)', '', '']

# %%
all_chunks = []
skip_markers = ["受注額合計", "仕入額合計", "粗利益", "利益率"]  # unwanted summary rows

for i, start_idx in enumerate(header_indices):
    end_idx = header_indices[i+1] if i+1 < len(header_indices) else len(df)

    # extract block
    block = df.iloc[start_idx:end_idx].reset_index(drop=True)

    # first row is the header
    header = block.iloc[0].fillna("").astype(str).tolist()
    print(header)

    # Make headers unique
    seen = {}
    unique_headers = []
    for col in header:
        if col in seen:
            seen[col] += 1
            unique_headers.append(f"{col}_{seen[col]}")
        else:
            seen[col] = 0
            unique_headers.append(col)

    block.columns = unique_headers
    block = block.drop(0).reset_index(drop=True)

    # --- Filter unwanted rows ---
    block = block[
        ~block.astype(str).apply(lambda row: any(marker in "".join(row) for marker in skip_markers), axis=1)
    ]

    # skip empty chunks
    if not block.empty:
        block["__TableBlock__"] = i + 1  # track which block/month
        all_chunks.append(block)

# Step 3: Combine everything
if not all_chunks:
    raise ValueError("No tables were found. Check key_column name.")

final_df = pd.concat(all_chunks, ignore_index=True)

# return final_df
# Out:
#   完了        _1 担当        受注番号                  受注日              得意先名 担当_1  #  \
# 0  済  04  17.0  M  O2304026M.  2023-04-03 00:00:00           株式会社ニコン   岩田  1
# 1  済  04  17.0  D   O2304043D  2023-04-03 00:00:00          株式会社ディスコ   村上  1
# 2  済  04  17.0  F   O2304049F  2023-04-03 00:00:00  株式会社トーメーコーポレーション   西尾  1
# 3  済  04  17.0  F   O2304049F  2023-04-03 00:00:00  株式会社トーメーコーポレーション   西尾  1
# 4  済  04  17.0  D   O2304055D  2023-04-03 00:00:00          株式会社ディスコ   村上  1
#
#                                                   型番  ...   _4 営業サイド自由記載  \
# 0  OEOFF-1986.5-0.05-3-0.05-99.9-2-PM-GDF-10/130-...  ...  NaN       NaN
# 1                 EYP-DFB-1064-00040-1500-BFY02-0006  ...  NaN       NaN
# 2                                 FCM-06-9-J0-2-L-RS  ...  NaN       NaN
# 3                                 FCM-06-9-J0-2-L-RS  ...  NaN       NaN
# 4                 EYP-DFB-1064-00040-1500-BFY02-0006  ...  NaN       NaN
#
#   __TableBlock__ ～2024/03納品 2024/04以降納品   _5   _6   _7 客先注文書番号   _8
# 0              1        NaN         NaN  NaN  NaN  NaN     NaN  NaN
# 1              1        NaN         NaN  NaN  NaN  NaN     NaN  NaN
# 2              1        NaN         NaN  NaN  NaN  NaN     NaN  NaN
# 3              1        NaN         NaN  NaN  NaN  NaN     NaN  NaN
# 4              1        NaN         NaN  NaN  NaN  NaN     NaN  NaN
#
# [5 rows x 61 columns]

# %%
import pandas as pd

def read_multi_table_excel(file_path, sheet_name=0, key_column="受注番号"):
    # Step 1: Read everything without headers
    df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)

    # Step 2: Detect header rows
    header_indices = df.index[
        df.apply(lambda row: row.astype(str).str.contains(key_column).any(), axis=1)
    ].tolist()

    all_chunks = []
    skip_markers = ["受注額合計", "仕入額合計", "粗利益", "利益率", "済"]

    for i, start_idx in enumerate(header_indices):
        end_idx = header_indices[i+1] if i+1 < len(header_indices) else len(df)

        # --- Extract block ---
        block = df.iloc[start_idx:end_idx].reset_index(drop=True)

        # --- First row is header ---
        header = block.iloc[0].fillna("").astype(str).tolist()

        # Make headers unique
        seen = {}
        unique_headers = []
        for col in header:
            if col in seen:
                seen[col] += 1
                unique_headers.append(f"{col}_{seen[col]}")
            else:
                seen[col] = 0
                unique_headers.append(col)

        block.columns = unique_headers
        block = block.drop(0).reset_index(drop=True)

        # --- Find stop point (summary/junk rows) ---
        stop_idx = None
        for j, row in block.iterrows():
            row_text = "".join(row.astype(str))
            if any(marker in row_text for marker in skip_markers):
                stop_idx = j
                break
        if stop_idx:
            block = block.iloc[:stop_idx]

        # --- Keep only non-empty block ---
        if not block.empty:
            block["__TableBlock__"] = i + 1
            all_chunks.append(block)

    if not all_chunks:
        raise ValueError("No valid tables found. Check key_column name.")

    final_df = pd.concat(all_chunks, ignore_index=True)
    return final_df
# Usage
file_path = "Sevensix_dropbox/機密レベル3/企画管理本部/業務推進部/売上台帳/18期_売上_納期管理台帳.xlsx"
clean_df = read_multi_table_excel(file_path,sheet_name="18期売上台帳", key_column="受注番号")

# %%
clean_df.head()
# Out:
#     完了        _1 担当       受注番号    受注日        得意先名 担当_1  #       型番  ...  \
# 0  NaN  NaN  9.0  E  O2409001E  45537  国立大学法人徳島大学    　  1  EB-FH52  ...
#
#   ﾊﾞｲﾔｰ希望納期 メーカ回答 (一次) メーカ回答 (二次) 備考(納期) 希望納期から遅延の理由 売上予定月       備考(作業用)   _6  \
# 0       NaN        NaN        NaN    NaN         NaN     1  O2408131E-2へ  NaN
#
#     _7 __TableBlock__
# 0  NaN             11
#
# [1 rows x 54 columns]

# %%
clean_df.shape
# Out:
# (1, 54)

# %%
block = block.dropna(how="all")

print(df.shape)
df = df.dropna(axis=1, how='all')  # Drop fully empty columns
print(df.shape)
# Out:
# (350735, 61)
# (350735, 60)
